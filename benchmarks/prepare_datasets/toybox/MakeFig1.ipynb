# %% [markdown]
# ## The figure with sample images from each age group

# %%
import sys, os

env_root = '/N/project/baby_vision_curriculum/pythonenvs/hfenv/lib/python3.10/site-packages/'
sys.path.insert(0, env_root)

# %%
import numpy as np
import torch, torchvision
from torchvision import transforms as tr
from tqdm import tqdm
from pathlib import Path
# import math
import argparse
import pandas as pd
import warnings

import matplotlib.pyplot as plt

# %%
jpg_root='/N/project/infant_image_statistics/preproc_saber/JPG_30fps/'

# %%
def get_fpathlist(vid_root, subjdir, ds_rate=1):
    """
    # read the image files inside vid_root/subj_dir into a list. 
    # makes sure they're all jpg. also sorts them so that the order of the frames is correct.
    # subjdir = ['008MS']
    """
    
    fpathlist = sorted(list(Path(os.path.join(vid_root, subjdir)).iterdir()), 
                       key=lambda x: x.name)
    fpathlist = [str(fpath) for fpath in fpathlist if fpath.suffix=='.jpg']
    fpathlist = fpathlist[::ds_rate]
    return fpathlist

# %%
g0='008MS+009SS+010BF+011EA+012TT+013LS+014SN+015JM+016TF+017EW'
g1='026AR+027SS+028CK+028MR+029TT+030FD+031HW+032SR+033SE+034JC'
g2='043MP+044ET+046TE+047MS+048KG+049JC+050AB+050AK+051DW'
g3='BR+CW+EA+ED+JB+KI+LS+SB+TR'
#     g0='008MS+009SS_withrotation+010BF_withrotation+011EA_withrotation+012TT_withrotation+013LS+014SN+015JM+016TF+017EW_withrotation'
#     g1='026AR+027SS+028CK+028MR+029TT+030FD+031HW+032SR+033SE+034JC_withlighting'
#     g2='043MP+044ET+046TE+047MS+048KG+049JC+050AB+050AK_rotation+051DW'

# Total number of frames in each age group: g0=1.68m, g1=1.77m, g2=1.45m


g0 = g0.split('+')
g1 = g1.split('+')
g2 = g2.split('+')
g3 = g3.split('+')

# %%
ds_rate = 3000

subj_dirs = g0


gx_fpathlist = []
for i_subj, subjdir in enumerate(tqdm(subj_dirs)):
    gx_fpathlist += get_fpathlist(jpg_root, subjdir, ds_rate=ds_rate)

# %%
image_paths = gx_fpathlist

# Create a figure with 4 rows and 4 columns
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10))

# Iterate over the image paths and plot one image every 1000
offset = 125#500
for i, image_path in enumerate(image_paths[offset:-1:1000]):
    row = i // 4  # Calculate the row index
    col = i % 4   # Calculate the column index

    # Load and display the image
    image = plt.imread(image_path)
    axes[row, col].imshow(image)
    axes[row, col].axis('off')

    # Add the index label to the image
    index = (i * 1000)+offset
    axes[row, col].text(10, 10, f"Index: {index}", color='white', backgroundcolor='black', fontsize=8)

# Adjust spacing and display the figure
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [28], in <cell line: 8>()
#      12 # Load and display the image
#      13 image = plt.imread(image_path)
# ---> 14 axes[row, col].imshow(image)
#      15 axes[row, col].axis('off')
#      17 # Add the index label to the image
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
group1_indices = [200, 3500, 1125, 5500, 8500] #200: ceiling,1125: mom face. 3500:corner seeing father. 5500: in crib. 8500:reading book. 
group1_images = [gx_fpathlist[idx]
                for idx in group1_indices]

# %%
image = plt.imread(group1_images[0])
plt.imshow(image)

# %%
ds_rate = 3000

subj_dirs = g1


gx_fpathlist = []
for i_subj, subjdir in enumerate(tqdm(subj_dirs)):
    gx_fpathlist += get_fpathlist(jpg_root, subjdir, ds_rate=ds_rate)
# Out:
# 100%|███████████████████████████████████████████| 10/10 [00:50<00:00,  5.02s/it]

# %%
len(gx_fpathlist)
# Out:
# 1778

# %%
image_paths = gx_fpathlist

# Create a figure with 4 rows and 4 columns
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10))

# Iterate over the image paths and plot one image every 1000
offset = 125#500
stride = 100
for i, image_path in enumerate(image_paths[offset:-1:stride]):
    row = i // 4  # Calculate the row index
    col = i % 4   # Calculate the column index

    # Load and display the image
    image = plt.imread(image_path)
    axes[row, col].imshow(image)
    axes[row, col].axis('off')

    # Add the index label to the image
    index = (i * stride)+offset
    axes[row, col].text(10, 10, f"Index: {index}", color='white', backgroundcolor='black', fontsize=8)

# Adjust spacing and display the figure
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [40], in <cell line: 9>()
#      13 # Load and display the image
#      14 image = plt.imread(image_path)
# ---> 15 axes[row, col].imshow(image)
#      16 axes[row, col].axis('off')
#      18 # Add the index label to the image
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
group2_indices = [721, 221, 321, 225, 625] #extra:6020#200: ceiling,1125: mom face. 3500:corner seeing father. 5500: in crib. 8500:reading book. 
# 1125, 5125, 11125, 15125, 2021 with stride=100 but w
group2_images = [gx_fpathlist[idx]
                for idx in group2_indices]

# %%
ds_rate = 3000

subj_dirs = g2


gx_fpathlist = []
for i_subj, subjdir in enumerate(tqdm(subj_dirs)):
    gx_fpathlist += get_fpathlist(jpg_root, subjdir, ds_rate=ds_rate)
# Out:
# 100%|█████████████████████████████████████████████| 9/9 [00:40<00:00,  4.47s/it]

# %%
image_paths = gx_fpathlist

# Create a figure with 4 rows and 4 columns
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10))

# Iterate over the image paths and plot one image every 1000
offset = 23#500
stride = 100
for i, image_path in enumerate(image_paths[offset:-1:stride]):
    row = i // 4  # Calculate the row index
    col = i % 4   # Calculate the column index

    # Load and display the image
    image = plt.imread(image_path)
    axes[row, col].imshow(image)
    axes[row, col].axis('off')

    # Add the index label to the image
    index = (i * stride)+offset
    axes[row, col].text(10, 10, f"Index: {index}", color='white', backgroundcolor='black', fontsize=8)

# Adjust spacing and display the figure
plt.tight_layout()

# %%
group3_indices = [1, 623, 903, 1003, 1244] #extra:
# 1125, 5125, 11125, 15125, 2021 with stride=100 but w
group3_images = [gx_fpathlist[idx]
                for idx in group3_indices]

# %%
ds_rate = 3000

subj_dirs = g3


gx_fpathlist = []
for i_subj, subjdir in enumerate(tqdm(subj_dirs)):
    gx_fpathlist += get_fpathlist(jpg_root, subjdir, ds_rate=ds_rate)
# Out:
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]

# %%
image_paths = gx_fpathlist

# Create a figure with 4 rows and 4 columns
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10))

# Iterate over the image paths and plot one image every 1000
offset = 7#500
stride = 50
for i, image_path in enumerate(image_paths[offset:-1:stride]):
    row = i // 4  # Calculate the row index
    col = i % 4   # Calculate the column index

    # Load and display the image
    image = plt.imread(image_path)
    axes[row, col].imshow(image)
    axes[row, col].axis('off')

    # Add the index label to the image
    index = (i * stride)+offset
    axes[row, col].text(10, 10, f"Index: {index}", color='white', backgroundcolor='black', fontsize=8)

# Adjust spacing and display the figure
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [68], in <cell line: 9>()
#      13 # Load and display the image
#      14 image = plt.imread(image_path)
# ---> 15 axes[row, col].imshow(image)
#      16 axes[row, col].axis('off')
#      18 # Add the index label to the image
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
group4_indices = [593, 23, 304, 507, 723] #extra:
# 1125, 5125, 11125, 15125, 2021 with stride=100 but w
group4_images = [gx_fpathlist[idx]
                for idx in group4_indices]

# %%
print(group1_images)
print(group2_images)
print(group3_images)
print(group4_images)
# Out:
# ['/N/project/infant_image_statistics/preproc_saber/JPG_30fps/008MS/008MS_0061345.jpg', '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/010BF/010BF_0231387.jpg', '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/008MS/008MS_0353869.jpg', '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/011EA/011EA_0496984.jpg', '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/013LS/013LS_0269320.jpg']
# ['/N/project/infant_image_statistics/preproc_saber/JPG_30fps/029TT/029TT_0143630.jpg', '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/027SS/027SS_0089122.jpg', '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/027SS/027SS_0398050.jpg', '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/027SS/027SS_0101122.jpg', '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/028MR/028MR_0348151.jpg']
# ...

# %%
# List of image paths for each group
group1_images = ['/N/project/infant_image_statistics/preproc_saber/JPG_30fps/008MS/008MS_0061345.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/010BF/010BF_0231387.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/008MS/008MS_0353869.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/011EA/011EA_0496984.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/013LS/013LS_0269320.jpg']
group2_images = ['/N/project/infant_image_statistics/preproc_saber/JPG_30fps/029TT/029TT_0143630.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/027SS/027SS_0089122.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/027SS/027SS_0398050.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/027SS/027SS_0101122.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/028MR/028MR_0348151.jpg']
group3_images = ['/N/project/infant_image_statistics/preproc_saber/JPG_30fps/043MP/043MP_0006356.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/048KG/048KG_0205467.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/049JC/049JC_0574238.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/050AB/050AB_0258411.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/050AK/050AK_0381259.jpg']
group4_images = ['/N/project/infant_image_statistics/preproc_saber/JPG_30fps/LS/LS.mp4_0123000.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/BR/BR_0069269.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/EA/EA.mp4_0009000.jpg', 
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/KI/KI.mp4_0228000.jpg',
                 '/N/project/infant_image_statistics/preproc_saber/JPG_30fps/SB/SB.mp4_0111000.jpg']

# Create a figure with four rows and five columns
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(12, 8))

# List of group image lists
group_images_list = [group1_images, group2_images, group3_images, group4_images]

# Iterate over each group and populate the figure
for i, group_images in enumerate(group_images_list):
    for j, image_path in enumerate(group_images):
        # Load and display the image
        image = plt.imread(image_path)
        axes[i, j].imshow(image)
        axes[i,j].set_xticks([])
        axes[i,j].set_yticks([])
#         axes[i, j].axis('off')

        # Add the index label to the image
#         index = i * len(group_images) + j + 1
#         axes[i, j].text(10, 10, f"Index: {index}", color='white', backgroundcolor='black', fontsize=8)

row_titles = ['2-4mo', '6-8mo', '10-12mo', 'Adult']
for i, ax in enumerate(axes[:, 0]):
    ax.set_ylabel(row_titles[i], rotation=90, fontsize=12, labelpad=10)

# Adjust spacing and display the figure
plt.tight_layout()
# plt.show()

plt.savefig('fig_sample_images.pdf', dpi=300)
