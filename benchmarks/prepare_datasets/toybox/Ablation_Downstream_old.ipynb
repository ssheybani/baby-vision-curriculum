# %%
import sys, os

env_root = '/N/project/baby_vision_curriculum/pythonenvs/hfenv/lib/python3.10/site-packages/'
sys.path.insert(0, env_root)

# %%
import numpy as np
import torch, torchvision
from torchvision import transforms as tr
from tqdm import tqdm
from pathlib import Path
# import math
import argparse
import pandas as pd
import warnings

from copy import deepcopy

# %%
from sklearn import svm, preprocessing
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def get_labels(fname):
#     example fname: truck_30_pivothead_rzminus.mp4
    fnparts = fname.split('.')[0].split('_')
    category = fnparts[0]
    identity = category+fnparts[1]
    trans = fnparts[3]
    return category, identity, trans

def get_categorylabel(fname):
    fnparts = fname.split('.')[0].split('_')
    category = fnparts[0]
    return category

def get_identitylabel(fname):
    fnparts = fname.split('.')[0].split('_')
    category = fnparts[0]
    identity = category+fnparts[1]
    return identity

def get_translabel(fname):
    fnparts = fname.split('.')[0].split('_')
    translabel = fnparts[3]
    return translabel

def add_labels_to_df(df, labels):
    if 'category' in labels:
        df['category'] = df['fnames'].apply(lambda fname: get_categorylabel(fname))
    if 'identity' in labels:
        df['identity'] = df['fnames'].apply(lambda fname: get_identitylabel(fname))
    if 'transformation' in labels:
        df['transformation'] = df['fnames'].apply(lambda fname: get_translabel(fname))
    return df

# %%
def get_separability_score(df, label, method='sgd', ret_preds=False):
    # method: sgd or svm
    le = preprocessing.LabelEncoder()
    y = le.fit_transform(df[label])
    
    X_cols = ['dim'+str(i)
              for i in range(768)]
    X = df[X_cols]
    
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    
    if method=='svm':
        clf = make_pipeline(StandardScaler(),
                            LinearSVC(random_state=0, tol=1e-4))
    elif method=='sgd':
        clf = make_pipeline(StandardScaler(),
                            SGDClassifier(max_iter=1000, tol=1e-4, n_jobs=20))#, loss='log_loss'))
    else:
        raise ValueError()
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train,y_train)
    test_score = clf.score(X_test,y_test)
    if ret_preds:
        preds = clf.predict(X_test)
        return train_score, test_score, preds, y_test
    return train_score, test_score

# %%
def fix_fnames(df):
    df.iloc[2163,0] = 'giraffe_02_pivothead_rzplus.mp4'
    df.iloc[1851,0]='duck_06_pivothead_rxminus.mp4'
    df.iloc[751,0] = 'car_03_pivothead_rzminus.mp4'
    return df

def eval_embs(fp, method='sgd', ret_preds=False):
    scores = {}
    
    df = pd.read_csv(fp)

#     fix 3 filenames. for older files
    df = fix_fnames(df)
    df = add_labels_to_df(df, ['category', 'identity','transformation'])
    
#     if ret_preds
    scores['category'] = get_separability_score(df, 'category', method=method)
#     scores['identity'] = get_separability_score(df, 'identity', method=method)
    scores['transformation'] = get_separability_score(df, 'transformation', method=method)
    return scores

# %%
def get_seed(fp):
    stem = Path(fp).stem
    parts = stem.split('_')
    return parts[3]

def get_tag(fp):
    # g0g1g2, g2g1g0, g3g1g2, grgrgr, g2g2g2
    # g0, g2, g3, gr
    # g0g1, g2g1, g2g2, grgr, g3g1
    stem = Path(fp).stem
    parts = stem.split('_')
    glast = parts[1]
    
    if 'pre' in stem:
        gpre = parts[-1]
        gpre = gpre.replace('pre.', '')
        
        full_tag = gpre+glast
    else:
        full_tag = glast
        
    return full_tag

def proc_fp(fp, score_type):
    df = pd.read_csv(fp)
    df = fix_fnames(df)
    df = add_labels_to_df(df, ['category', 'identity','transformation'])
    method='sgd'
    train_score, test_score, preds, targets = get_separability_score(df, score_type, method=method, ret_preds=True)
    return test_score

def get_ablation_cond(fp):
    stem = Path(fp).stem
    parts = stem.split('_')
#     other_id = parts[5]
    cond = parts[4]
    return cond


tagname_dict = {
    'g0':'g0g1g2', 
    'g0g1': 'g0g1g2', 
    'g0g1g2': 'g0g1g2',
    'g2':'g2g1g0', 
    'g2g1': 'g2g1g0', 
    'g2g1g0': 'g2g1g0'}

# %% [markdown]
# ## Make the default condition

# %%
default_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/may14/'#s3/'

# %%
def_record_list = []
iter_per_stage = 5000
for stage in range(1,4):
    emb_dir = default_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         print(tag)
        if ('gr' in tag) |\
    ('g3' in tag) |\
    ('g0g0' in tag) |\
    ('g2g2' in tag):
            continue # skip other curricula
        
#         curr = tagname_dict[tag]
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': tag,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        def_record_list.append(deepcopy(record))
df_def = pd.DataFrame.from_records(def_record_list)
# df_def = df_def.rename(columns={
#     'tag': 'Curriculum',
#     'iteration': 'Iteration'
# })
df_def
# Out:
# 100%|███████████████████████████████████████████| 18/18 [00:20<00:00,  1.15s/it]
# 100%|███████████████████████████████████████████| 21/21 [00:10<00:00,  2.03it/s]
# 100%|███████████████████████████████████████████| 21/21 [00:12<00:00,  1.65it/s]
#                                   fname Curriculum  Iteration  Accuracy
# 0            embeddings_g2_seed_212_sgd         g2       5000  0.269339
# 1           embeddings_g0_seed_662__sgd         g0       5000  0.389592
# 2            embeddings_g0_seed_213_sgd         g0       5000  0.362166
# 3            embeddings_g2_seed_211_sgd         g2       5000  0.225035
# 4           embeddings_g2_seed_563__sgd         g2       5000  0.266526
# 5            embeddings_g2_seed_213_sgd         g2       5000  0.261603
# 6           embeddings_g0_seed_661__sgd         g0       5000  0.412799
# 7            embeddings_g0_seed_212_sgd         g0       5000  0.356540
# 8           embeddings_g2_seed_561__sgd         g2       5000  0.274262
# 9           embeddings_g2_seed_562__sgd         g2       5000  0.259494
# 10           embeddings_g0_seed_211_sgd         g0       5000  0.378340
# 11          embeddings_g0_seed_663__sgd         g0       5000  0.393812
# 12    embeddings_g1_seed_211_sgd_pre.g0       g0g1      10000  0.401547
# 13    embeddings_g1_seed_213_sgd_pre.g2       g2g1      10000  0.301688
# 14    embeddings_g1_seed_212_sgd_pre.g0       g0g1      10000  0.397328
# 15    embeddings_g1_seed_211_sgd_pre.g2       g2g1      10000  0.239100
# 16    embeddings_g1_seed_213_sgd_pre.g0       g0g1      10000  0.407173
# 17    embeddings_g1_seed_212_sgd_pre.g2       g2g1      10000  0.277075
# 18  embeddings_g2_seed_211_sgd_pre.g0g1     g0g1g2      15000  0.414205
# 19  embeddings_g2_seed_212_sgd_pre.g0g1     g0g1g2      15000  0.414909
# 20  embeddings_g2_seed_213_sgd_pre.g0g1     g0g1g2      15000  0.419128
# 21  embeddings_g0_seed_213_sgd_pre.g2g1     g2g1g0      15000  0.304501
# 22  embeddings_g0_seed_211_sgd_pre.g2g1     g2g1g0      15000  0.187060
# 23  embeddings_g0_seed_212_sgd_pre.g2g1     g2g1g0      15000  0.344585

# %%
defsp_record_list = []
iter_per_stage = 5000
for stage in range(1,4):
    emb_dir = default_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         print(tag)
        if ('gr' in tag) |\
    ('g3' in tag) |\
    ('g0g0' in tag) |\
    ('g2g2' in tag):
            continue # skip other curricula
        
#         curr = tagname_dict[tag]
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': tag,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        defsp_record_list.append(deepcopy(record))
df_defsp = pd.DataFrame.from_records(defsp_record_list)
# df_def = df_def.rename(columns={
#     'tag': 'Curriculum',
#     'iteration': 'Iteration'
# })
df_defsp
# Out:
# 100%|███████████████████████████████████████████| 18/18 [00:17<00:00,  1.00it/s]
# 100%|███████████████████████████████████████████| 21/21 [00:09<00:00,  2.32it/s]
#   0%|                                                    | 0/21 [00:00<?, ?it/s]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 21/21 [00:11<00:00,  1.76it/s]
#                                   fname Curriculum  Iteration  Accuracy
# 0            embeddings_g2_seed_212_sgd         g2       5000  0.405767
# 1           embeddings_g0_seed_662__sgd         g0       5000  0.518987
# 2            embeddings_g0_seed_213_sgd         g0       5000  0.455696
# 3            embeddings_g2_seed_211_sgd         g2       5000  0.434599
# 4           embeddings_g2_seed_563__sgd         g2       5000  0.447257
# 5            embeddings_g2_seed_213_sgd         g2       5000  0.427567
# 6           embeddings_g0_seed_661__sgd         g0       5000  0.514065
# 7            embeddings_g0_seed_212_sgd         g0       5000  0.480309
# 8           embeddings_g2_seed_561__sgd         g2       5000  0.464838
# 9           embeddings_g2_seed_562__sgd         g2       5000  0.436006
# 10           embeddings_g0_seed_211_sgd         g0       5000  0.502110
# 11          embeddings_g0_seed_663__sgd         g0       5000  0.537271
# 12    embeddings_g1_seed_211_sgd_pre.g0       g0g1      10000  0.575949
# 13    embeddings_g1_seed_213_sgd_pre.g2       g2g1      10000  0.440225
# 14    embeddings_g1_seed_212_sgd_pre.g0       g0g1      10000  0.553446
# 15    embeddings_g1_seed_211_sgd_pre.g2       g2g1      10000  0.431786
# 16    embeddings_g1_seed_213_sgd_pre.g0       g0g1      10000  0.540788
# 17    embeddings_g1_seed_212_sgd_pre.g2       g2g1      10000  0.430380
# 18  embeddings_g2_seed_211_sgd_pre.g0g1     g0g1g2      15000  0.616034
# 19  embeddings_g2_seed_212_sgd_pre.g0g1     g0g1g2      15000  0.629395
# 20  embeddings_g2_seed_213_sgd_pre.g0g1     g0g1g2      15000  0.643460
# 21  embeddings_g0_seed_213_sgd_pre.g2g1     g2g1g0      15000  0.490155
# 22  embeddings_g0_seed_211_sgd_pre.g2g1     g2g1g0      15000  0.371308
# 23  embeddings_g0_seed_212_sgd_pre.g2g1     g2g1g0      15000  0.505626

# %% [markdown]
# ## Frame Rate

# %%
# Prepare a copy of df_def with the condition column added

dfdef_fr = deepcopy(df_def)
dfdef_fr['Condition'] = '30fps'

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/ablations/frame_rate/'

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_fr = pd.DataFrame.from_records(record_list)
df_fr

# %%
df_fr = pd.concat((df_fr, dfdef_fr)) #add the default condition
df_fr

# %%
# shades_blue = ["#377eb8"]*3 # "#6baed6", "#9ecae1"]
# shades_orange = ["#e6550d"]*3#, "#fd8d3c", "#fdae6b"]

# Combine the shades into a single color palette
# custom_palette = shades_blue + shades_orange

# %%
hue_order = ['g0g1g2',
            'g2g1g0']
style_order=['10fps','15fps','30fps']

# %%
# df_all['Curriculum'].map(tagname_dict)
# df_all['Curriculum'] = df_all['Curriculum'].map(tagname_dict)

# %%
# df_all = deepcopy(df_fr)
cdata = df_all

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, linewidth=4.5,
#             hue_order=hue_order, style_order=style_order, palette=custom_palette)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
# sns.lineplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, linestyle='--', legend=False)
# sns.scatterplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, legend=False, s=10)

ax.axhline(y=0.2, color='gray', linestyle='solid')


ax.axvline(x=5000, color='gray', linestyle=':')
ax.axvline(x=10000, color='gray', linestyle=':')
ax.axvline(x=15000, color='gray', linestyle=':')

ax.set_xlim([1000.,16000])
ax.set_ylim([0.16,0.5])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
# ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
#             arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 1', xy=(5000, 0.45), xytext=(5500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 2', xy=(10000, 0.45), xytext=(10500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 3', xy=(15000, 0.45), xytext=(15500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


# plt.savefig('fig_sup_toybox_categorization_framerate.pdf', dpi=300)

# %% [markdown]
# ## Number of Iterations

# %%
# Prepare a copy of df_def with the condition column added

dfdef_niter = deepcopy(df_def)
dfdef_niter['Condition'] = 'nep5'

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/ablations/num_ep/'

# %%
# # fix the filenames
# for stage in range(1,4):
#     emb_dir = emb_root+'s'+str(stage)+'/'
#     directory = emb_dir
#     for filename in os.listdir(directory):
#         if 'sgd' in filename:
#             new_filename = filename.replace('sgd', 'nep2')
#             old_path = os.path.join(directory, filename)
#             new_path = os.path.join(directory, new_filename)
#             os.rename(old_path, new_path)

# %%
record_list = []
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
        
        if cond=='nep2':
            iter_per_stage = 2000 #@@
        elif cond=='nep5':
            iter_per_stage = 5000 #@@
        elif cond=='nep15':
            iter_per_stage = 15000 #@@
        
        
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_niter = pd.DataFrame.from_records(record_list)
df_niter = pd.concat((df_niter, dfdef_niter)) #add the default condition
df_niter

# %%
hue_order = ['g0g1g2',
            'g2g1g0']
style_order=['nep2','nep5','nep15']

# %%
df_all = deepcopy(df_niter)
df_all['Curriculum'] = df_all['Curriculum'].map(tagname_dict)
cdata = df_all

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, linewidth=4.5,
#             hue_order=hue_order, style_order=style_order, palette=custom_palette)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
# sns.lineplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, linestyle='--', legend=False)
# sns.scatterplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, legend=False, s=10)

ax.axhline(y=0.2, color='gray', linestyle='solid')


ax.axvline(x=2000, color='gray', linestyle='solid')
ax.axvline(x=4000, color='gray', linestyle='solid')
ax.axvline(x=6000, color='gray', linestyle='solid')

ax.axvline(x=5000, color='gray', linestyle='dashed')
ax.axvline(x=10000, color='gray', linestyle='dashed')
ax.axvline(x=15000, color='gray', linestyle='dashed')

ax.axvline(x=15000, color='gray', linestyle='dotted')
ax.axvline(x=30000, color='gray', linestyle='dotted')
ax.axvline(x=45000, color='gray', linestyle='dotted')

# ax.set_xlim([1000.,16000])
ax.set_ylim([0.16,0.5])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
# ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
#             arrowprops=dict(facecolor='black', shrink=0.05))
# ax.annotate('End of Stage 1', xy=(5000, 0.45), xytext=(5500, 0.45),
#             arrowprops=dict(facecolor='black', shrink=0.05))
# ax.annotate('End of Stage 2', xy=(10000, 0.45), xytext=(10500, 0.45),
#             arrowprops=dict(facecolor='black', shrink=0.05))
# ax.annotate('End of Stage 3', xy=(15000, 0.45), xytext=(15500, 0.45),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


plt.savefig('fig_sup_toybox_categorization_niter.pdf', dpi=300)

# %% [markdown]
# ## Optimizer

# %%
# Prepare a copy of df_def with the condition column added

dfdef_optim = deepcopy(df_def)
dfdef_optim['Condition'] = 'sgd'

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/ablations/optim/'

# %%
iter_per_stage = 5000 #@@
record_list = []
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
        
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_optim = pd.DataFrame.from_records(record_list)
df_optim = pd.concat((df_optim, dfdef_optim)) #add the default condition
df_optim
# Out:
# 100%|███████████████████████████████████████████| 18/18 [00:29<00:00,  1.61s/it]
# 100%|███████████████████████████████████████████| 18/18 [00:27<00:00,  1.50s/it]
# 100%|███████████████████████████████████████████| 18/18 [00:29<00:00,  1.66s/it]
#                                   fname Curriculum Condition  Iteration  \
# 0           embeddings_g2_seed_223_adam     g2g1g0      adam       5000
# 1           embeddings_g0_seed_233_adam     g0g1g2      adam       5000
# 2           embeddings_g0_seed_221_adam     g0g1g2      adam       5000
# 3           embeddings_g0_seed_231_adam     g0g1g2      adam       5000
# 4          embeddings_g2_seed_223_adamw     g2g1g0     adamw       5000
# ..                                  ...        ...       ...        ...
# 19  embeddings_g2_seed_212_sgd_pre.g0g1     g0g1g2       sgd      15000
# 20  embeddings_g2_seed_213_sgd_pre.g0g1     g0g1g2       sgd      15000
# 21  embeddings_g0_seed_213_sgd_pre.g2g1     g2g1g0       sgd      15000
# 22  embeddings_g0_seed_211_sgd_pre.g2g1     g2g1g0       sgd      15000
# 23  embeddings_g0_seed_212_sgd_pre.g2g1     g2g1g0       sgd      15000
#
#     Accuracy
# 0   0.094233
# 1   0.338959
# 2   0.109705
# 3   0.284107
# 4   0.412799
# ..       ...
# 19  0.405063
# 20  0.407876
# 21  0.353727
# 22  0.192686
# 23  0.342475
#
# [78 rows x 5 columns]

# %%
hue_order = ['g0g1g2',
            'g2g1g0']
style_order=['sgd','adam','adamw']

# %%
df_all = deepcopy(df_optim)
df_all['Curriculum'] = df_all['Curriculum'].map(tagname_dict)
cdata = df_all

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, linewidth=4.5,
#             hue_order=hue_order, style_order=style_order, palette=custom_palette)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
# sns.lineplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, linestyle='--', legend=False)
# sns.scatterplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, legend=False, s=10)

ax.axhline(y=0.2, color='gray', linestyle='solid')


# ax.axvline(x=2000, color='gray', linestyle='solid')
# ax.axvline(x=4000, color='gray', linestyle='solid')
# ax.axvline(x=6000, color='gray', linestyle='solid')

ax.axvline(x=5000, color='gray', linestyle='dotted')
ax.axvline(x=10000, color='gray', linestyle='dotted')
ax.axvline(x=15000, color='gray', linestyle='dotted')

# ax.axvline(x=15000, color='gray', linestyle='dotted')
# ax.axvline(x=30000, color='gray', linestyle='dotted')
# ax.axvline(x=45000, color='gray', linestyle='dotted')

ax.set_xlim([1000.,16000])
ax.set_ylim([0.16,0.5])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 1', xy=(5000, 0.45), xytext=(5500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 2', xy=(10000, 0.45), xytext=(10500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 3', xy=(15000, 0.45), xytext=(15500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


plt.savefig('fig_sup_toybox_categorization_optim.pdf', dpi=300)

# %% [markdown]
# ## Static Frame

# %%
# Prepare a copy of df_def with the condition column added

dfdef_static = deepcopy(df_def)
dfdef_static['Condition'] = 'video'

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/ablations/static_frame/'

# %%
ablation_cond = 'static'
iter_per_stage = 5000 #@@
record_list = []
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = ablation_cond#get_ablation_cond(fp)
        
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_static = pd.DataFrame.from_records(record_list)
df_static = pd.concat((df_static, dfdef_static)) #add the default condition
df_static
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.80s/it]
# 100%|█████████████████████████████████████████████| 2/2 [00:04<00:00,  2.04s/it]
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.96s/it]
#                                      fname Curriculum Condition  Iteration  \
# 0            embeddings_g0_seed_413_static     g0g1g2    static       5000
# 1            embeddings_g0_seed_223_static     g0g1g2    static       5000
# 2     embeddings_g1_seed_413_static_pre.g0     g0g1g2    static      10000
# 3     embeddings_g1_seed_223_static_pre.g0     g0g1g2    static      10000
# 4   embeddings_g2_seed_223_static_pre.g0g1     g0g1g2    static      15000
# 5   embeddings_g2_seed_413_static_pre.g0g1     g0g1g2    static      15000
# 0               embeddings_g2_seed_212_sgd         g2     video       5000
# 1              embeddings_g0_seed_662__sgd         g0     video       5000
# 2               embeddings_g0_seed_213_sgd         g0     video       5000
# 3               embeddings_g2_seed_211_sgd         g2     video       5000
# 4              embeddings_g2_seed_563__sgd         g2     video       5000
# 5               embeddings_g2_seed_213_sgd         g2     video       5000
# 6              embeddings_g0_seed_661__sgd         g0     video       5000
# 7               embeddings_g0_seed_212_sgd         g0     video       5000
# 8              embeddings_g2_seed_561__sgd         g2     video       5000
# 9              embeddings_g2_seed_562__sgd         g2     video       5000
# 10              embeddings_g0_seed_211_sgd         g0     video       5000
# 11             embeddings_g0_seed_663__sgd         g0     video       5000
# 12       embeddings_g1_seed_211_sgd_pre.g0       g0g1     video      10000
# 13       embeddings_g1_seed_213_sgd_pre.g2       g2g1     video      10000
# 14       embeddings_g1_seed_212_sgd_pre.g0       g0g1     video      10000
# 15       embeddings_g1_seed_211_sgd_pre.g2       g2g1     video      10000
# 16       embeddings_g1_seed_213_sgd_pre.g0       g0g1     video      10000
# 17       embeddings_g1_seed_212_sgd_pre.g2       g2g1     video      10000
# 18     embeddings_g2_seed_211_sgd_pre.g0g1     g0g1g2     video      15000
# 19     embeddings_g2_seed_212_sgd_pre.g0g1     g0g1g2     video      15000
# 20     embeddings_g2_seed_213_sgd_pre.g0g1     g0g1g2     video      15000
# 21     embeddings_g0_seed_213_sgd_pre.g2g1     g2g1g0     video      15000
# 22     embeddings_g0_seed_211_sgd_pre.g2g1     g2g1g0     video      15000
# 23     embeddings_g0_seed_212_sgd_pre.g2g1     g2g1g0     video      15000
#
#     Accuracy
# 0   0.238397
# 1   0.281997
# 2   0.338959
# 3   0.331927
# 4   0.379044
# 5   0.393108
# 0   0.248242
# 1   0.401547
# 2   0.345992
# 3   0.263010
# 4   0.268636
# 5   0.253868
# 6   0.407173
# 7   0.375527
# 8   0.285513
# 9   0.258790
# 10  0.338256
# 11  0.386076
# 12  0.399437
# 13  0.288326
# 14  0.405063
# 15  0.280591
# 16  0.390999
# 17  0.285513
# 18  0.398031
# 19  0.400141
# 20  0.414205
# 21  0.341772
# 22  0.216596
# 23  0.341772

# %%
hue_order = ['g0g1g2',
            'g2g1g0']
style_order=['video','static']

# %%
df_all = deepcopy(df_static)
df_all['Curriculum'] = df_all['Curriculum'].map(tagname_dict)
cdata = df_all

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, linewidth=4.5,
#             hue_order=hue_order, style_order=style_order, palette=custom_palette)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
# sns.lineplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, linestyle='--', legend=False)
# sns.scatterplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, legend=False, s=10)

ax.axhline(y=0.2, color='gray', linestyle='solid')


# ax.axvline(x=2000, color='gray', linestyle='solid')
# ax.axvline(x=4000, color='gray', linestyle='solid')
# ax.axvline(x=6000, color='gray', linestyle='solid')

ax.axvline(x=5000, color='gray', linestyle='dotted')
ax.axvline(x=10000, color='gray', linestyle='dotted')
ax.axvline(x=15000, color='gray', linestyle='dotted')

# ax.axvline(x=15000, color='gray', linestyle='dotted')
# ax.axvline(x=30000, color='gray', linestyle='dotted')
# ax.axvline(x=45000, color='gray', linestyle='dotted')

ax.set_xlim([1000.,16000])
ax.set_ylim([0.16,0.5])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 1', xy=(5000, 0.45), xytext=(5500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 2', xy=(10000, 0.45), xytext=(10500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 3', xy=(15000, 0.45), xytext=(15500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


# plt.savefig('fig_sup_toybox_categorization_static.pdf', dpi=300)
# Out:
# Text(15500, 0.45, 'End of Stage 3')

# %%
# Spatial transformation

dfdef_static_sp = deepcopy(df_defsp)
dfdef_static_sp['Condition'] = 'video'

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/ablations/static_frame/'

# %%
ablation_cond = 'static'
iter_per_stage = 5000 #@@
record_list = []
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = ablation_cond#get_ablation_cond(fp)
        
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_static_sp = pd.DataFrame.from_records(record_list)
df_static_sp = pd.concat((df_static_sp, dfdef_static_sp)) #add the default condition
df_static_sp
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:02<00:00,  1.32s/it]
# 100%|█████████████████████████████████████████████| 2/2 [00:02<00:00,  1.42s/it]
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.73s/it]
#                                      fname Curriculum Condition  Iteration  \
# 0            embeddings_g0_seed_413_static     g0g1g2    static       5000
# 1            embeddings_g0_seed_223_static     g0g1g2    static       5000
# 2     embeddings_g1_seed_413_static_pre.g0     g0g1g2    static      10000
# 3     embeddings_g1_seed_223_static_pre.g0     g0g1g2    static      10000
# 4   embeddings_g2_seed_223_static_pre.g0g1     g0g1g2    static      15000
# 5   embeddings_g2_seed_413_static_pre.g0g1     g0g1g2    static      15000
# 0               embeddings_g2_seed_212_sgd         g2     video       5000
# 1              embeddings_g0_seed_662__sgd         g0     video       5000
# 2               embeddings_g0_seed_213_sgd         g0     video       5000
# 3               embeddings_g2_seed_211_sgd         g2     video       5000
# 4              embeddings_g2_seed_563__sgd         g2     video       5000
# 5               embeddings_g2_seed_213_sgd         g2     video       5000
# 6              embeddings_g0_seed_661__sgd         g0     video       5000
# 7               embeddings_g0_seed_212_sgd         g0     video       5000
# 8              embeddings_g2_seed_561__sgd         g2     video       5000
# 9              embeddings_g2_seed_562__sgd         g2     video       5000
# 10              embeddings_g0_seed_211_sgd         g0     video       5000
# 11             embeddings_g0_seed_663__sgd         g0     video       5000
# 12       embeddings_g1_seed_211_sgd_pre.g0       g0g1     video      10000
# 13       embeddings_g1_seed_213_sgd_pre.g2       g2g1     video      10000
# 14       embeddings_g1_seed_212_sgd_pre.g0       g0g1     video      10000
# 15       embeddings_g1_seed_211_sgd_pre.g2       g2g1     video      10000
# 16       embeddings_g1_seed_213_sgd_pre.g0       g0g1     video      10000
# 17       embeddings_g1_seed_212_sgd_pre.g2       g2g1     video      10000
# 18     embeddings_g2_seed_211_sgd_pre.g0g1     g0g1g2     video      15000
# 19     embeddings_g2_seed_212_sgd_pre.g0g1     g0g1g2     video      15000
# 20     embeddings_g2_seed_213_sgd_pre.g0g1     g0g1g2     video      15000
# 21     embeddings_g0_seed_213_sgd_pre.g2g1     g2g1g0     video      15000
# 22     embeddings_g0_seed_211_sgd_pre.g2g1     g2g1g0     video      15000
# 23     embeddings_g0_seed_212_sgd_pre.g2g1     g2g1g0     video      15000
#
#     Accuracy
# 0   0.425457
# 1   0.434599
# 2   0.490155
# 3   0.491561
# 4   0.511955
# 5   0.521800
# 0   0.414909
# 1   0.511252
# 2   0.477496
# 3   0.428270
# 4   0.444444
# 5   0.420534
# 6   0.514065
# 7   0.500703
# 8   0.407876
# 9   0.424754
# 10  0.509142
# 11  0.528129
# 12  0.568917
# 13  0.429677
# 14  0.553446
# 15  0.464838
# 16  0.563994
# 17  0.452883
# 18  0.616034
# 19  0.609001
# 20  0.643460
# 21  0.482419
# 22  0.394515
# 23  0.501406

# %%
hue_order = ['g0g1g2',
            'g2g1g0']
style_order=['video','static']

# %%
df_all = deepcopy(df_static_sp)
df_all['Curriculum'] = df_all['Curriculum'].map(tagname_dict)
cdata = df_all

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, linewidth=4.5,
#             hue_order=hue_order, style_order=style_order, palette=custom_palette)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
# sns.lineplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, linestyle='--', legend=False)
# sns.scatterplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, legend=False, s=10)

ax.axhline(y=0.45, color='gray', linestyle='solid')


# ax.axvline(x=2000, color='gray', linestyle='solid')
# ax.axvline(x=4000, color='gray', linestyle='solid')
# ax.axvline(x=6000, color='gray', linestyle='solid')

ax.axvline(x=5000, color='gray', linestyle='dotted')
ax.axvline(x=10000, color='gray', linestyle='dotted')
ax.axvline(x=15000, color='gray', linestyle='dotted')

# ax.axvline(x=15000, color='gray', linestyle='dotted')
# ax.axvline(x=30000, color='gray', linestyle='dotted')
# ax.axvline(x=45000, color='gray', linestyle='dotted')

ax.set_xlim([1000.,16000])
ax.set_ylim([0.16,0.7])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 1', xy=(5000, 0.45), xytext=(5500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 2', xy=(10000, 0.45), xytext=(10500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 3', xy=(15000, 0.45), xytext=(15500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


# plt.savefig('fig_sup_toybox_categorization_static.pdf', dpi=300)
# Out:
# Text(15500, 0.45, 'End of Stage 3')

# %% [markdown]
# ## Shuffle

# %%
# Prepare a copy of df_def with the condition column added

dfdef_shuff = deepcopy(df_def)
dfdef_shuff['Condition'] = 'ordered'

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/ablations/shuffle/'

# %%
ablation_cond = 'shuffled'
iter_per_stage = 5000 #@@
record_list = []
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = ablation_cond#get_ablation_cond(fp)
        
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_shuff = pd.DataFrame.from_records(record_list)
df_shuff = pd.concat((df_shuff, dfdef_shuff)) #add the default condition
df_shuff
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:04<00:00,  2.04s/it]
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.64s/it]
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.68s/it]
#                                       fname Curriculum Condition  Iteration  \
# 0            embeddings_g0_seed_363_shuffle     g0g1g2  shuffled       5000
# 1            embeddings_g0_seed_361_shuffle     g0g1g2  shuffled       5000
# 2     embeddings_g1_seed_363_shuffle_pre.g0     g0g1g2  shuffled      10000
# 3     embeddings_g1_seed_361_shuffle_pre.g0     g0g1g2  shuffled      10000
# 4   embeddings_g2_seed_363_shuffle_pre.g0g1     g0g1g2  shuffled      15000
# 5   embeddings_g2_seed_361_shuffle_pre.g0g1     g0g1g2  shuffled      15000
# 0                embeddings_g2_seed_212_sgd         g2   ordered       5000
# 1               embeddings_g0_seed_662__sgd         g0   ordered       5000
# 2                embeddings_g0_seed_213_sgd         g0   ordered       5000
# 3                embeddings_g2_seed_211_sgd         g2   ordered       5000
# 4               embeddings_g2_seed_563__sgd         g2   ordered       5000
# 5                embeddings_g2_seed_213_sgd         g2   ordered       5000
# 6               embeddings_g0_seed_661__sgd         g0   ordered       5000
# 7                embeddings_g0_seed_212_sgd         g0   ordered       5000
# 8               embeddings_g2_seed_561__sgd         g2   ordered       5000
# 9               embeddings_g2_seed_562__sgd         g2   ordered       5000
# 10               embeddings_g0_seed_211_sgd         g0   ordered       5000
# 11              embeddings_g0_seed_663__sgd         g0   ordered       5000
# 12        embeddings_g1_seed_211_sgd_pre.g0       g0g1   ordered      10000
# 13        embeddings_g1_seed_213_sgd_pre.g2       g2g1   ordered      10000
# 14        embeddings_g1_seed_212_sgd_pre.g0       g0g1   ordered      10000
# 15        embeddings_g1_seed_211_sgd_pre.g2       g2g1   ordered      10000
# 16        embeddings_g1_seed_213_sgd_pre.g0       g0g1   ordered      10000
# 17        embeddings_g1_seed_212_sgd_pre.g2       g2g1   ordered      10000
# 18      embeddings_g2_seed_211_sgd_pre.g0g1     g0g1g2   ordered      15000
# 19      embeddings_g2_seed_212_sgd_pre.g0g1     g0g1g2   ordered      15000
# 20      embeddings_g2_seed_213_sgd_pre.g0g1     g0g1g2   ordered      15000
# 21      embeddings_g0_seed_213_sgd_pre.g2g1     g2g1g0   ordered      15000
# 22      embeddings_g0_seed_211_sgd_pre.g2g1     g2g1g0   ordered      15000
# 23      embeddings_g0_seed_212_sgd_pre.g2g1     g2g1g0   ordered      15000
#
#     Accuracy
# 0   0.322785
# 1   0.339662
# 2   0.387482
# 3   0.405767
# 4   0.421941
# 5   0.416315
# 0   0.269339
# 1   0.389592
# 2   0.362166
# 3   0.225035
# 4   0.266526
# 5   0.261603
# 6   0.412799
# 7   0.356540
# 8   0.274262
# 9   0.259494
# 10  0.378340
# 11  0.393812
# 12  0.401547
# 13  0.301688
# 14  0.397328
# 15  0.239100
# 16  0.407173
# 17  0.277075
# 18  0.414205
# 19  0.414909
# 20  0.419128
# 21  0.304501
# 22  0.187060
# 23  0.344585

# %%
hue_order = ['g0g1g2',
            'g2g1g0']
style_order=['ordered','shuffled']

# %%
df_all = deepcopy(df_shuff)
df_all['Curriculum'] = df_all['Curriculum'].map(tagname_dict)
cdata = df_all

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, linewidth=4.5,
#             hue_order=hue_order, style_order=style_order, palette=custom_palette)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
# sns.lineplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, linestyle='--', legend=False)
# sns.scatterplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, legend=False, s=10)

ax.axhline(y=0.2, color='gray', linestyle='solid')


# ax.axvline(x=2000, color='gray', linestyle='solid')
# ax.axvline(x=4000, color='gray', linestyle='solid')
# ax.axvline(x=6000, color='gray', linestyle='solid')

ax.axvline(x=5000, color='gray', linestyle='dotted')
ax.axvline(x=10000, color='gray', linestyle='dotted')
ax.axvline(x=15000, color='gray', linestyle='dotted')

# ax.axvline(x=15000, color='gray', linestyle='dotted')
# ax.axvline(x=30000, color='gray', linestyle='dotted')
# ax.axvline(x=45000, color='gray', linestyle='dotted')

ax.set_xlim([1000.,16000])
ax.set_ylim([0.16,0.5])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 1', xy=(5000, 0.45), xytext=(5500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 2', xy=(10000, 0.45), xytext=(10500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 3', xy=(15000, 0.45), xytext=(15500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


# plt.savefig('fig_sup_toybox_categorization_static.pdf', dpi=300)
# Out:
# Text(15500, 0.45, 'End of Stage 3')

# %%
# Prepare a copy of df_def with the condition column added

dfdef_shuff_sp = deepcopy(df_defsp)
dfdef_shuff_sp['Condition'] = 'ordered'

# %%
ablation_cond = 'shuffled'
iter_per_stage = 5000 #@@
record_list = []
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = ablation_cond#get_ablation_cond(fp)
        
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_shuff_sp = pd.DataFrame.from_records(record_list)
df_shuff_sp = pd.concat((df_shuff_sp, dfdef_shuff_sp)) #add the default condition
df_shuff_sp
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:02<00:00,  1.39s/it]
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.77s/it]
# 100%|█████████████████████████████████████████████| 2/2 [00:04<00:00,  2.02s/it]
#                                       fname Curriculum Condition  Iteration  \
# 0            embeddings_g0_seed_363_shuffle     g0g1g2  shuffled       5000
# 1            embeddings_g0_seed_361_shuffle     g0g1g2  shuffled       5000
# 2     embeddings_g1_seed_363_shuffle_pre.g0     g0g1g2  shuffled      10000
# 3     embeddings_g1_seed_361_shuffle_pre.g0     g0g1g2  shuffled      10000
# 4   embeddings_g2_seed_363_shuffle_pre.g0g1     g0g1g2  shuffled      15000
# 5   embeddings_g2_seed_361_shuffle_pre.g0g1     g0g1g2  shuffled      15000
# 0                embeddings_g2_seed_212_sgd         g2   ordered       5000
# 1               embeddings_g0_seed_662__sgd         g0   ordered       5000
# 2                embeddings_g0_seed_213_sgd         g0   ordered       5000
# 3                embeddings_g2_seed_211_sgd         g2   ordered       5000
# 4               embeddings_g2_seed_563__sgd         g2   ordered       5000
# 5                embeddings_g2_seed_213_sgd         g2   ordered       5000
# 6               embeddings_g0_seed_661__sgd         g0   ordered       5000
# 7                embeddings_g0_seed_212_sgd         g0   ordered       5000
# 8               embeddings_g2_seed_561__sgd         g2   ordered       5000
# 9               embeddings_g2_seed_562__sgd         g2   ordered       5000
# 10               embeddings_g0_seed_211_sgd         g0   ordered       5000
# 11              embeddings_g0_seed_663__sgd         g0   ordered       5000
# 12        embeddings_g1_seed_211_sgd_pre.g0       g0g1   ordered      10000
# 13        embeddings_g1_seed_213_sgd_pre.g2       g2g1   ordered      10000
# 14        embeddings_g1_seed_212_sgd_pre.g0       g0g1   ordered      10000
# 15        embeddings_g1_seed_211_sgd_pre.g2       g2g1   ordered      10000
# 16        embeddings_g1_seed_213_sgd_pre.g0       g0g1   ordered      10000
# 17        embeddings_g1_seed_212_sgd_pre.g2       g2g1   ordered      10000
# 18      embeddings_g2_seed_211_sgd_pre.g0g1     g0g1g2   ordered      15000
# 19      embeddings_g2_seed_212_sgd_pre.g0g1     g0g1g2   ordered      15000
# 20      embeddings_g2_seed_213_sgd_pre.g0g1     g0g1g2   ordered      15000
# 21      embeddings_g0_seed_213_sgd_pre.g2g1     g2g1g0   ordered      15000
# 22      embeddings_g0_seed_211_sgd_pre.g2g1     g2g1g0   ordered      15000
# 23      embeddings_g0_seed_212_sgd_pre.g2g1     g2g1g0   ordered      15000
#
#     Accuracy
# 0   0.489451
# 1   0.488748
# 2   0.525316
# 3   0.535162
# 4   0.565401
# 5   0.594937
# 0   0.405767
# 1   0.518987
# 2   0.455696
# 3   0.434599
# 4   0.447257
# 5   0.427567
# 6   0.514065
# 7   0.480309
# 8   0.464838
# 9   0.436006
# 10  0.502110
# 11  0.537271
# 12  0.575949
# 13  0.440225
# 14  0.553446
# 15  0.431786
# 16  0.540788
# 17  0.430380
# 18  0.616034
# 19  0.629395
# 20  0.643460
# 21  0.490155
# 22  0.371308
# 23  0.505626

# %%
df_all = deepcopy(df_shuff_sp)
df_all['Curriculum'] = df_all['Curriculum'].map(tagname_dict)
cdata = df_all

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, linewidth=4.5,
#             hue_order=hue_order, style_order=style_order, palette=custom_palette)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
# sns.lineplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, linestyle='--', legend=False)
# sns.scatterplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, legend=False, s=10)

ax.axhline(y=0.45, color='gray', linestyle='solid')


# ax.axvline(x=2000, color='gray', linestyle='solid')
# ax.axvline(x=4000, color='gray', linestyle='solid')
# ax.axvline(x=6000, color='gray', linestyle='solid')

ax.axvline(x=5000, color='gray', linestyle='dotted')
ax.axvline(x=10000, color='gray', linestyle='dotted')
ax.axvline(x=15000, color='gray', linestyle='dotted')

# ax.axvline(x=15000, color='gray', linestyle='dotted')
# ax.axvline(x=30000, color='gray', linestyle='dotted')
# ax.axvline(x=45000, color='gray', linestyle='dotted')

ax.set_xlim([1000.,16000])
ax.set_ylim([0.3,0.7])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 1', xy=(5000, 0.65), xytext=(5500, 0.65),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 2', xy=(10000, 0.65), xytext=(10500, 0.65),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 3', xy=(15000, 0.65), xytext=(15500, 0.65),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


# plt.savefig('fig_sup_toybox_categorization_static.pdf', dpi=300)
# Out:
# Text(15500, 0.65, 'End of Stage 3')

# %% [markdown]
# ## Slowness
# 10fps.
# static vs shuffle vs normal (default)

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/ablations/slowness/'

# %%
def get_ablation_cond(fp):
    stem = Path(fp).stem
    parts = stem.split('_')
#     other_id = parts[5]
    cond = parts[4]
    return cond

# %%
iter_per_stage = 5000 #@@
record_list = []
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
        
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_slowness = pd.DataFrame.from_records(record_list)
# df_slowness = pd.concat((df_optim, dfdef_optim)) #add the default condition
df_slowness
# Out:
# 100%|███████████████████████████████████████████| 20/20 [00:35<00:00,  1.78s/it]
# 100%|███████████████████████████████████████████| 20/20 [00:37<00:00,  1.86s/it]
# 100%|███████████████████████████████████████████| 19/19 [00:36<00:00,  1.91s/it]
#                                           fname Curriculum    Condition  \
# 0                embeddings_g0_seed_682_default     g0g1g2      default
# 1                embeddings_g2_seed_683_shuffle     g2g1g0      shuffle
# 2                embeddings_g0_seed_683_shuffle     g0g1g2      shuffle
# 3            embeddings_g0_seed_682_longshuffle     g0g1g2  longshuffle
# 4                embeddings_g2_seed_683_default     g2g1g0      default
# 5            embeddings_g0_seed_681_longshuffle     g0g1g2  longshuffle
# 6                embeddings_g0_seed_681_default     g0g1g2      default
# 7            embeddings_g0_seed_683_longshuffle     g0g1g2  longshuffle
# 8                 embeddings_g0_seed_683_static     g0g1g2       static
# 9                 embeddings_g0_seed_681_static     g0g1g2       static
# 10               embeddings_g2_seed_681_shuffle     g2g1g0      shuffle
# 11               embeddings_g0_seed_683_default     g0g1g2      default
# 12               embeddings_g2_seed_682_default     g2g1g0      default
# 13               embeddings_g0_seed_681_shuffle     g0g1g2      shuffle
# 14                embeddings_g0_seed_682_static     g0g1g2       static
# 15                embeddings_g2_seed_682_static     g2g1g0       static
# 16                embeddings_g2_seed_683_static     g2g1g0       static
# 17               embeddings_g0_seed_682_shuffle     g0g1g2      shuffle
# 18                embeddings_g2_seed_681_static     g2g1g0       static
# 19               embeddings_g2_seed_682_shuffle     g2g1g0      shuffle
# 20         embeddings_g1_seed_682_static_pre.g2     g2g1g0       static
# 21         embeddings_g1_seed_683_static_pre.g2     g2g1g0       static
# 22        embeddings_g1_seed_682_default_pre.g2     g2g1g0      default
# 23         embeddings_g1_seed_683_static_pre.g0     g0g1g2       static
# 24        embeddings_g1_seed_681_shuffle_pre.g0     g0g1g2      shuffle
# 25         embeddings_g1_seed_682_static_pre.g0     g0g1g2       static
# 26        embeddings_g1_seed_682_shuffle_pre.g2     g2g1g0      shuffle
# 27        embeddings_g1_seed_681_shuffle_pre.g2     g2g1g0      shuffle
# 28        embeddings_g1_seed_681_default_pre.g0     g0g1g2      default
# 29         embeddings_g1_seed_681_static_pre.g0     g0g1g2       static
# 30        embeddings_g1_seed_683_default_pre.g2     g2g1g0      default
# 31        embeddings_g1_seed_682_shuffle_pre.g0     g0g1g2      shuffle
# 32        embeddings_g1_seed_682_default_pre.g0     g0g1g2      default
# 33    embeddings_g1_seed_681_longshuffle_pre.g0     g0g1g2  longshuffle
# 34        embeddings_g1_seed_683_shuffle_pre.g2     g2g1g0      shuffle
# 35    embeddings_g1_seed_682_longshuffle_pre.g0     g0g1g2  longshuffle
# 36    embeddings_g1_seed_683_longshuffle_pre.g0     g0g1g2  longshuffle
# 37        embeddings_g1_seed_683_shuffle_pre.g0     g0g1g2      shuffle
# 38         embeddings_g1_seed_681_static_pre.g2     g2g1g0       static
# 39        embeddings_g1_seed_683_default_pre.g0     g0g1g2      default
# 40      embeddings_g0_seed_682_default_pre.g2g1     g2g1g0      default
# 41      embeddings_g2_seed_683_default_pre.g0g1     g0g1g2      default
# 42       embeddings_g0_seed_682_static_pre.g2g1     g2g1g0       static
# 43  embeddings_g2_seed_681_longshuffle_pre.g0g1     g0g1g2  longshuffle
# 44      embeddings_g2_seed_681_default_pre.g0g1     g0g1g2      default
# 45      embeddings_g2_seed_682_shuffle_pre.g0g1     g0g1g2      shuffle
# 46       embeddings_g0_seed_683_static_pre.g2g1     g2g1g0       static
# 47       embeddings_g2_seed_681_static_pre.g0g1     g0g1g2       static
# 48  embeddings_g2_seed_683_longshuffle_pre.g0g1     g0g1g2  longshuffle
# 49      embeddings_g0_seed_683_default_pre.g2g1     g2g1g0      default
# 50      embeddings_g2_seed_681_shuffle_pre.g0g1     g0g1g2      shuffle
# 51  embeddings_g2_seed_682_longshuffle_pre.g0g1     g0g1g2  longshuffle
# 52      embeddings_g0_seed_681_shuffle_pre.g2g1     g2g1g0      shuffle
# 53       embeddings_g2_seed_683_static_pre.g0g1     g0g1g2       static
# 54      embeddings_g0_seed_683_shuffle_pre.g2g1     g2g1g0      shuffle
# 55      embeddings_g0_seed_682_shuffle_pre.g2g1     g2g1g0      shuffle
# 56      embeddings_g2_seed_683_shuffle_pre.g0g1     g0g1g2      shuffle
# 57      embeddings_g2_seed_682_default_pre.g0g1     g0g1g2      default
# 58       embeddings_g0_seed_681_static_pre.g2g1     g2g1g0       static
#
#     Iteration  Accuracy
# 0        5000  0.358650
# 1        5000  0.258087
# 2        5000  0.271449
# 3        5000  0.259494
# 4        5000  0.263713
# 5        5000  0.272855
# 6        5000  0.362869
# 7        5000  0.254571
# 8        5000  0.372714
# 9        5000  0.376934
# 10       5000  0.291842
# 11       5000  0.337553
# 12       5000  0.260900
# 13       5000  0.296062
# 14       5000  0.381857
# 15       5000  0.249648
# 16       5000  0.255274
# 17       5000  0.306610
# 18       5000  0.253165
# 19       5000  0.231364
# 20      10000  0.265120
# 21      10000  0.276371
# 22      10000  0.234880
# 23      10000  0.383966
# 24      10000  0.360056
# 25      10000  0.388186
# 26      10000  0.238397
# 27      10000  0.258087
# 28      10000  0.407876
# 29      10000  0.402250
# 30      10000  0.261603
# 31      10000  0.357243
# 32      10000  0.402250
# 33      10000  0.293952
# 34      10000  0.253165
# 35      10000  0.308720
# 36      10000  0.305907
# 37      10000  0.345992
# 38      10000  0.281997
# 39      10000  0.400141
# 40      15000  0.316456
# 41      15000  0.419831
# 42      15000  0.408579
# 43      15000  0.335443
# 44      15000  0.424051
# 45      15000  0.410689
# 46      15000  0.388889
# 47      15000  0.417018
# 48      15000  0.305204
# 49      15000  0.267229
# 50      15000  0.395921
# 51      15000  0.298172
# 52      15000  0.260900
# 53      15000  0.403657
# 54      15000  0.251055
# 55      15000  0.220816
# 56      15000  0.418425
# 57      15000  0.419128
# 58      15000  0.367089

# %%
hue_order = ['g0g1g2',
            'g2g1g0']
style_order=['static','default','shuffle', 'longshuffle']

# %%
df_all = deepcopy(df_slowness)
df_all['Curriculum'] = df_all['Curriculum'].map(tagname_dict)
cdata = df_all

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, linewidth=4.5,
#             hue_order=hue_order, style_order=style_order, palette=custom_palette)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
# sns.lineplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, linestyle='--', legend=False)
# sns.scatterplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, legend=False, s=10)

ax.axhline(y=0.2, color='gray', linestyle='solid')


# ax.axvline(x=2000, color='gray', linestyle='solid')
# ax.axvline(x=4000, color='gray', linestyle='solid')
# ax.axvline(x=6000, color='gray', linestyle='solid')

ax.axvline(x=5000, color='gray', linestyle='dotted')
ax.axvline(x=10000, color='gray', linestyle='dotted')
ax.axvline(x=15000, color='gray', linestyle='dotted')

# ax.axvline(x=15000, color='gray', linestyle='dotted')
# ax.axvline(x=30000, color='gray', linestyle='dotted')
# ax.axvline(x=45000, color='gray', linestyle='dotted')

ax.set_xlim([1000.,16000])
ax.set_ylim([0.16,0.5])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 1', xy=(5000, 0.45), xytext=(5500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 2', xy=(10000, 0.45), xytext=(10500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 3', xy=(15000, 0.45), xytext=(15500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


# plt.savefig('fig_sup_toybox_categorization_static.pdf', dpi=300)
# Out:
# Text(15500, 0.45, 'End of Stage 3')

# %%
iter_per_stage = 5000 #@@
record_list = []
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
        
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_slowness_sp = pd.DataFrame.from_records(record_list)
# df_slowness = pd.concat((df_optim, dfdef_optim)) #add the default condition
df_slowness_sp
# Out:
# 100%|███████████████████████████████████████████| 20/20 [00:28<00:00,  1.43s/it]
# 100%|███████████████████████████████████████████| 20/20 [00:31<00:00,  1.56s/it]
# 100%|███████████████████████████████████████████| 19/19 [00:31<00:00,  1.65s/it]
#                                           fname Curriculum    Condition  \
# 0                embeddings_g0_seed_682_default     g0g1g2      default
# 1                embeddings_g2_seed_683_shuffle     g2g1g0      shuffle
# 2                embeddings_g0_seed_683_shuffle     g0g1g2      shuffle
# 3            embeddings_g0_seed_682_longshuffle     g0g1g2  longshuffle
# 4                embeddings_g2_seed_683_default     g2g1g0      default
# 5            embeddings_g0_seed_681_longshuffle     g0g1g2  longshuffle
# 6                embeddings_g0_seed_681_default     g0g1g2      default
# 7            embeddings_g0_seed_683_longshuffle     g0g1g2  longshuffle
# 8                 embeddings_g0_seed_683_static     g0g1g2       static
# 9                 embeddings_g0_seed_681_static     g0g1g2       static
# 10               embeddings_g2_seed_681_shuffle     g2g1g0      shuffle
# 11               embeddings_g0_seed_683_default     g0g1g2      default
# 12               embeddings_g2_seed_682_default     g2g1g0      default
# 13               embeddings_g0_seed_681_shuffle     g0g1g2      shuffle
# 14                embeddings_g0_seed_682_static     g0g1g2       static
# 15                embeddings_g2_seed_682_static     g2g1g0       static
# 16                embeddings_g2_seed_683_static     g2g1g0       static
# 17               embeddings_g0_seed_682_shuffle     g0g1g2      shuffle
# 18                embeddings_g2_seed_681_static     g2g1g0       static
# 19               embeddings_g2_seed_682_shuffle     g2g1g0      shuffle
# 20         embeddings_g1_seed_682_static_pre.g2     g2g1g0       static
# 21         embeddings_g1_seed_683_static_pre.g2     g2g1g0       static
# 22        embeddings_g1_seed_682_default_pre.g2     g2g1g0      default
# 23         embeddings_g1_seed_683_static_pre.g0     g0g1g2       static
# 24        embeddings_g1_seed_681_shuffle_pre.g0     g0g1g2      shuffle
# 25         embeddings_g1_seed_682_static_pre.g0     g0g1g2       static
# 26        embeddings_g1_seed_682_shuffle_pre.g2     g2g1g0      shuffle
# 27        embeddings_g1_seed_681_shuffle_pre.g2     g2g1g0      shuffle
# 28        embeddings_g1_seed_681_default_pre.g0     g0g1g2      default
# 29         embeddings_g1_seed_681_static_pre.g0     g0g1g2       static
# 30        embeddings_g1_seed_683_default_pre.g2     g2g1g0      default
# 31        embeddings_g1_seed_682_shuffle_pre.g0     g0g1g2      shuffle
# 32        embeddings_g1_seed_682_default_pre.g0     g0g1g2      default
# 33    embeddings_g1_seed_681_longshuffle_pre.g0     g0g1g2  longshuffle
# 34        embeddings_g1_seed_683_shuffle_pre.g2     g2g1g0      shuffle
# 35    embeddings_g1_seed_682_longshuffle_pre.g0     g0g1g2  longshuffle
# 36    embeddings_g1_seed_683_longshuffle_pre.g0     g0g1g2  longshuffle
# 37        embeddings_g1_seed_683_shuffle_pre.g0     g0g1g2      shuffle
# 38         embeddings_g1_seed_681_static_pre.g2     g2g1g0       static
# 39        embeddings_g1_seed_683_default_pre.g0     g0g1g2      default
# 40      embeddings_g0_seed_682_default_pre.g2g1     g2g1g0      default
# 41      embeddings_g2_seed_683_default_pre.g0g1     g0g1g2      default
# 42       embeddings_g0_seed_682_static_pre.g2g1     g2g1g0       static
# 43  embeddings_g2_seed_681_longshuffle_pre.g0g1     g0g1g2  longshuffle
# 44      embeddings_g2_seed_681_default_pre.g0g1     g0g1g2      default
# 45      embeddings_g2_seed_682_shuffle_pre.g0g1     g0g1g2      shuffle
# 46       embeddings_g0_seed_683_static_pre.g2g1     g2g1g0       static
# 47       embeddings_g2_seed_681_static_pre.g0g1     g0g1g2       static
# 48  embeddings_g2_seed_683_longshuffle_pre.g0g1     g0g1g2  longshuffle
# 49      embeddings_g0_seed_683_default_pre.g2g1     g2g1g0      default
# 50      embeddings_g2_seed_681_shuffle_pre.g0g1     g0g1g2      shuffle
# 51  embeddings_g2_seed_682_longshuffle_pre.g0g1     g0g1g2  longshuffle
# 52      embeddings_g0_seed_681_shuffle_pre.g2g1     g2g1g0      shuffle
# 53       embeddings_g2_seed_683_static_pre.g0g1     g0g1g2       static
# 54      embeddings_g0_seed_683_shuffle_pre.g2g1     g2g1g0      shuffle
# 55      embeddings_g0_seed_682_shuffle_pre.g2g1     g2g1g0      shuffle
# 56      embeddings_g2_seed_683_shuffle_pre.g0g1     g0g1g2      shuffle
# 57      embeddings_g2_seed_682_default_pre.g0g1     g0g1g2      default
# 58       embeddings_g0_seed_681_static_pre.g2g1     g2g1g0       static
#
#     Iteration  Accuracy
# 0        5000  0.490155
# 1        5000  0.436006
# 2        5000  0.488748
# 3        5000  0.443741
# 4        5000  0.431083
# 5        5000  0.450774
# 6        5000  0.512658
# 7        5000  0.428270
# 8        5000  0.492968
# 9        5000  0.503516
# 10       5000  0.462025
# 11       5000  0.488748
# 12       5000  0.435302
# 13       5000  0.470464
# 14       5000  0.488748
# 15       5000  0.436709
# 16       5000  0.436709
# 17       5000  0.485935
# 18       5000  0.433193
# 19       5000  0.427567
# 20      10000  0.441632
# 21      10000  0.449367
# 22      10000  0.430380
# 23      10000  0.506329
# 24      10000  0.557665
# 25      10000  0.497187
# 26      10000  0.443038
# 27      10000  0.438115
# 28      10000  0.549930
# 29      10000  0.520394
# 30      10000  0.383966
# 31      10000  0.571730
# 32      10000  0.554149
# 33      10000  0.485232
# 34      10000  0.449367
# 35      10000  0.492264
# 36      10000  0.481013
# 37      10000  0.555556
# 38      10000  0.426160
# 39      10000  0.563291
# 40      15000  0.457103
# 41      15000  0.599859
# 42      15000  0.473277
# 43      15000  0.547117
# 44      15000  0.580872
# 45      15000  0.578059
# 46      15000  0.455696
# 47      15000  0.502110
# 48      15000  0.478200
# 49      15000  0.407876
# 50      15000  0.566104
# 51      15000  0.509845
# 52      15000  0.445851
# 53      15000  0.490858
# 54      15000  0.447257
# 55      15000  0.459916
# 56      15000  0.574543
# 57      15000  0.586498
# 58      15000  0.467651

# %%
df_all = deepcopy(df_slowness_sp)
df_all['Curriculum'] = df_all['Curriculum'].map(tagname_dict)
cdata = df_all

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, linewidth=4.5,
#             hue_order=hue_order, style_order=style_order, palette=custom_palette)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
# sns.lineplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, linestyle='--', legend=False)
# sns.scatterplot(data=df_all, x='Iteration', y='Validation Loss', hue='Curriculum', ax=ax, legend=False, s=10)

ax.axhline(y=0.45, color='gray', linestyle='solid')


# ax.axvline(x=2000, color='gray', linestyle='solid')
# ax.axvline(x=4000, color='gray', linestyle='solid')
# ax.axvline(x=6000, color='gray', linestyle='solid')

ax.axvline(x=5000, color='gray', linestyle='dotted')
ax.axvline(x=10000, color='gray', linestyle='dotted')
ax.axvline(x=15000, color='gray', linestyle='dotted')

# ax.axvline(x=15000, color='gray', linestyle='dotted')
# ax.axvline(x=30000, color='gray', linestyle='dotted')
# ax.axvline(x=45000, color='gray', linestyle='dotted')

ax.set_xlim([1000.,16000])
ax.set_ylim([0.3,0.7])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 1', xy=(5000, 0.65), xytext=(5500, 0.65),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 2', xy=(10000, 0.65), xytext=(10500, 0.65),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 3', xy=(15000, 0.65), xytext=(15500, 0.65),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


# plt.savefig('fig_sup_toybox_categorization_static.pdf', dpi=300)
# Out:
# Text(15500, 0.65, 'End of Stage 3')

# %%
def get_separability_score(df, label, method='sgd', ret_preds=False):
    # method: sgd or svm
#     le = preprocessing.LabelEncoder()
    y = df[label] #le.fit_transform(df[label])
    
    X_cols = ['dim'+str(i)
              for i in range(768)]
    X = df[X_cols]
    
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    
    if method=='svm':
        clf = make_pipeline(StandardScaler(),
                            LinearSVC(random_state=0, tol=1e-4))
    elif method=='sgd':
        clf = make_pipeline(StandardScaler(),
                            SGDClassifier(max_iter=1000, tol=1e-4, n_jobs=60))#, loss='log_loss'))
    else:
        raise ValueError()
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train,y_train)
    test_score = clf.score(X_test,y_test)
    if ret_preds:
        preds = clf.predict(X_test)
        return train_score, test_score, preds, y_test
    return train_score, test_score

# %%
def get_tag(fp):
    # g0g1g2, g2g1g0, g3g1g2, grgrgr, g2g2g2
    # g0, g2, g3, gr
    # g0g1, g2g1, g2g2, grgr, g3g1
    stem = Path(fp).stem
    parts = stem.split('_')
    glast = parts[2]
    
    if 'pre' in stem:
        gpre = parts[-1]
        gpre = gpre.replace('pre.', '')
        
        full_tag = gpre+glast
    else:
        full_tag = glast
    return full_tag

def get_ablation_cond(fp):
    stem = Path(fp).stem
    parts = stem.split('_')
#     other_id = parts[5]
    cond = parts[7]
    return cond

def proc_fp(fp):
    df = pd.read_csv(fp)
    
    method='sgd'
    train_score, test_score = get_separability_score(df, 'labels', method=method, ret_preds=False)
    return test_score

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/ucf101/ablations/slowness/'

# %%
# # temp: when we want to add the longshuffle condition, but not recompute everything
# record_list = []
# iter_per_stage = 5000
# for stage in range(1,4):
#     emb_dir = emb_root+'s'+str(stage)+'/'
#     fpathlist = [emb_dir+fname
#                 for fname in os.listdir(emb_dir)
#                 if Path(emb_dir+fname).suffix=='.csv']
#     for i, fp in enumerate(tqdm(fpathlist)):
#         if Path(fp).stem.split('_')[1]=='na':
#             continue
#         tag = get_tag(fp)
#         curr = tagname_dict[tag]
#         cond = get_ablation_cond(fp)
        
#         if cond!='longshuffle':
#             continue
        
#         tag = tag.replace('g3','ga')
#         score = proc_fp(fp)
#         record = {'fname': Path(fp).stem,
#                   'tag': tag,
#                   'Curriculum': curr,
#                   'Condition': cond,
#                  'Iteration': iter_per_stage*stage,
#                   'Accuracy': score}
#         record_list.append(deepcopy(record))
        
# xdf_longshuffle = pd.DataFrame.from_records(record_list)
# df_slowness_ucf = pd.concat((df_slowness_ucf, xdf_longshuffle))

# %%
record_list = []
iter_per_stage = 5000
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
        if Path(fp).stem.split('_')[1]=='na':
            continue
        tag = get_tag(fp)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
        
        if (curr=='Youngest Only') | (curr=='Oldest Only'):
            continue
        tag = tag.replace('g3','ga')
        score = proc_fp(fp)
        record = {'fname': Path(fp).stem,
                  'tag': tag,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
# Out:
#   0%|                                                    | 0/16 [00:00<?, ?it/s]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#   6%|██▊                                         | 1/16 [01:20<20:04, 80.33s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  12%|█████▌                                      | 2/16 [02:45<19:28, 83.45s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  19%|████████▎                                   | 3/16 [03:59<17:08, 79.08s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  25%|███████████                                 | 4/16 [05:21<16:02, 80.21s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  31%|█████████████▊                              | 5/16 [06:47<15:04, 82.19s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  38%|████████████████▌                           | 6/16 [08:04<13:24, 80.50s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  44%|███████████████████▎                        | 7/16 [09:07<11:12, 74.75s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  50%|██████████████████████                      | 8/16 [10:07<09:20, 70.08s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  56%|████████████████████████▊                   | 9/16 [11:28<08:34, 73.56s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  62%|██████████████████████████▉                | 10/16 [12:48<07:32, 75.49s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  69%|█████████████████████████████▌             | 11/16 [13:43<05:46, 69.22s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  75%|████████████████████████████████▎          | 12/16 [14:55<04:40, 70.02s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  81%|██████████████████████████████████▉        | 13/16 [15:52<03:17, 65.93s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  88%|█████████████████████████████████████▋     | 14/16 [17:12<02:20, 70.43s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  94%|████████████████████████████████████████▎  | 15/16 [18:30<01:12, 72.47s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 16/16 [19:52<00:00, 74.51s/it]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#   7%|██▉                                         | 1/15 [01:12<16:54, 72.43s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  13%|█████▊                                      | 2/15 [02:09<13:45, 63.52s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  20%|████████▊                                   | 3/15 [02:58<11:20, 56.70s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  27%|███████████▋                                | 4/15 [04:08<11:21, 61.99s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  33%|██████████████▋                             | 5/15 [05:22<11:04, 66.45s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  40%|█████████████████▌                          | 6/15 [06:36<10:21, 69.06s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  47%|████████████████████▌                       | 7/15 [07:42<09:03, 67.97s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  53%|███████████████████████▍                    | 8/15 [08:59<08:16, 70.88s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  60%|██████████████████████████▍                 | 9/15 [09:36<06:01, 60.19s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  67%|████████████████████████████▋              | 10/15 [10:14<04:27, 53.41s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  73%|███████████████████████████████▌           | 11/15 [11:07<03:33, 53.32s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  80%|██████████████████████████████████▍        | 12/15 [11:50<02:30, 50.08s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  87%|█████████████████████████████████████▎     | 13/15 [13:17<02:02, 61.17s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  93%|████████████████████████████████████████▏  | 14/15 [14:41<01:08, 68.33s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 15/15 [16:08<00:00, 64.55s/it]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#   7%|██▉                                         | 1/15 [00:37<08:49, 37.81s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  13%|█████▊                                      | 2/15 [02:00<13:54, 64.21s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  20%|████████▊                                   | 3/15 [03:12<13:35, 67.95s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  27%|███████████▋                                | 4/15 [04:22<12:36, 68.75s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  33%|██████████████▋                             | 5/15 [05:47<12:23, 74.32s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  40%|█████████████████▌                          | 6/15 [07:05<11:21, 75.74s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  47%|████████████████████▌                       | 7/15 [07:39<08:15, 61.98s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  53%|███████████████████████▍                    | 8/15 [08:15<06:16, 53.78s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  60%|██████████████████████████▍                 | 9/15 [09:24<05:50, 58.42s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  67%|████████████████████████████▋              | 10/15 [10:06<04:26, 53.40s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  73%|███████████████████████████████▌           | 11/15 [10:56<03:29, 52.46s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  80%|██████████████████████████████████▍        | 12/15 [11:33<02:22, 47.64s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  87%|█████████████████████████████████████▎     | 13/15 [12:28<01:40, 50.11s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  93%|████████████████████████████████████████▏  | 14/15 [13:06<00:46, 46.27s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 15/15 [13:40<00:00, 54.69s/it]

# %%
df_slowness_ucf= pd.DataFrame.from_records(record_list)
# df_slowness = pd.concat((df_optim, dfdef_optim)) #add the default condition
df_slowness_ucf

# %%
# df_slowness_ucf.to_csv('df_slowness_ucf.csv', index=False)
# df_slowness_ucf = pd.read_csv('df_slowness_ucf.csv')
df_slowness_ucf

# %%
# for index, row in df_slowness_ucf.iterrows():
#     cond = row['fname'].split('_')[7]
# #     print(cond)
#     df_slowness_ucf.at[index, 'Condition'] = cond

# %%
df_slowness_ucf
# Out:
#                                                 fname     tag Curriculum  \
# 0      embeddings_model_g0_seed_683_other_683_shuffle      g0     g0g1g2
# 1      embeddings_model_g2_seed_683_other_683_default      g2     g2g1g0
# 2      embeddings_model_g0_seed_681_other_681_shuffle      g0     g0g1g2
# 3      embeddings_model_g2_seed_681_other_681_shuffle      g2     g2g1g0
# 4       embeddings_model_g2_seed_681_other_681_static      g2     g2g1g0
# 5       embeddings_model_g2_seed_683_other_683_static      g2     g2g1g0
# 6      embeddings_model_g0_seed_683_other_683_default      g0     g0g1g2
# 7      embeddings_model_g0_seed_681_other_681_default      g0     g0g1g2
# 8      embeddings_model_g2_seed_682_other_682_shuffle      g2     g2g1g0
# 9      embeddings_model_g2_seed_683_other_683_shuffle      g2     g2g1g0
# 10      embeddings_model_g0_seed_681_other_681_static      g0     g0g1g2
# 11     embeddings_model_g0_seed_682_other_682_default      g0     g0g1g2
# 12      embeddings_model_g0_seed_682_other_682_static      g0     g0g1g2
# 13      embeddings_model_g2_seed_682_other_682_static      g2     g2g1g0
# 14     embeddings_model_g0_seed_682_other_682_shuffle      g0     g0g1g2
# 15     embeddings_model_g2_seed_682_other_682_default      g2     g2g1g0
# 16  embeddings_model_g1_seed_683_other_683_static_...    g2g1     g2g1g0
# 17  embeddings_model_g1_seed_682_other_682_shuffle...    g0g1     g0g1g2
# 18  embeddings_model_g1_seed_681_other_681_static_...    g0g1     g0g1g2
# 19  embeddings_model_g1_seed_682_other_682_static_...    g2g1     g2g1g0
# 20  embeddings_model_g1_seed_682_other_682_shuffle...    g2g1     g2g1g0
# 21  embeddings_model_g1_seed_683_other_683_default...    g2g1     g2g1g0
# 22  embeddings_model_g1_seed_681_other_681_shuffle...    g0g1     g0g1g2
# 23  embeddings_model_g1_seed_681_other_681_shuffle...    g2g1     g2g1g0
# 24  embeddings_model_g1_seed_682_other_682_default...    g0g1     g0g1g2
# 25  embeddings_model_g1_seed_683_other_683_default...    g0g1     g0g1g2
# 26  embeddings_model_g1_seed_683_other_683_shuffle...    g0g1     g0g1g2
# 27  embeddings_model_g1_seed_681_other_681_default...    g0g1     g0g1g2
# 28  embeddings_model_g1_seed_683_other_683_shuffle...    g2g1     g2g1g0
# 29  embeddings_model_g1_seed_682_other_682_default...    g2g1     g2g1g0
# 30  embeddings_model_g1_seed_681_other_681_static_...    g2g1     g2g1g0
# 31  embeddings_model_g2_seed_681_other_681_default...  g0g1g2     g0g1g2
# 32  embeddings_model_g0_seed_682_other_682_default...  g2g1g0     g2g1g0
# 33  embeddings_model_g0_seed_683_other_683_shuffle...  g2g1g0     g2g1g0
# 34  embeddings_model_g0_seed_683_other_683_default...  g2g1g0     g2g1g0
# 35  embeddings_model_g0_seed_681_other_681_shuffle...  g2g1g0     g2g1g0
# 36  embeddings_model_g0_seed_682_other_682_shuffle...  g2g1g0     g2g1g0
# 37  embeddings_model_g2_seed_682_other_682_shuffle...  g0g1g2     g0g1g2
# 38  embeddings_model_g2_seed_683_other_683_shuffle...  g0g1g2     g0g1g2
# 39  embeddings_model_g0_seed_683_other_683_static_...  g2g1g0     g2g1g0
# 40  embeddings_model_g2_seed_681_other_681_static_...  g0g1g2     g0g1g2
# 41  embeddings_model_g0_seed_681_other_681_static_...  g2g1g0     g2g1g0
# 42  embeddings_model_g2_seed_682_other_682_default...  g0g1g2     g0g1g2
# 43  embeddings_model_g0_seed_682_other_682_static_...  g2g1g0     g2g1g0
# 44  embeddings_model_g2_seed_681_other_681_shuffle...  g0g1g2     g0g1g2
# 45  embeddings_model_g2_seed_683_other_683_default...  g0g1g2     g0g1g2
# 0   embeddings_model_g0_seed_682_other_682_longshu...      g0     g0g1g2
# 1   embeddings_model_g0_seed_683_other_683_longshu...      g0     g0g1g2
# 2   embeddings_model_g0_seed_681_other_681_longshu...      g0     g0g1g2
# 3   embeddings_model_g1_seed_682_other_682_longshu...    g0g1     g0g1g2
# 4   embeddings_model_g1_seed_683_other_683_longshu...    g0g1     g0g1g2
# 5   embeddings_model_g1_seed_681_other_681_longshu...    g0g1     g0g1g2
# 6   embeddings_model_g2_seed_681_other_681_longshu...  g0g1g2     g0g1g2
# 7   embeddings_model_g2_seed_683_other_683_longshu...  g0g1g2     g0g1g2
# 8   embeddings_model_g2_seed_682_other_682_longshu...  g0g1g2     g0g1g2
#
#       Condition  Iteration  Accuracy
# 0       shuffle       5000  0.176029
# 1       default       5000  0.156698
# 2       shuffle       5000  0.177621
# 3       shuffle       5000  0.165113
# 4        static       5000  0.164658
# 5        static       5000  0.153059
# 6       default       5000  0.244712
# 7       default       5000  0.258131
# 8       shuffle       5000  0.155788
# 9       shuffle       5000  0.152604
# 10       static       5000  0.277689
# 11      default       5000  0.265863
# 12       static       5000  0.283602
# 13       static       5000  0.160337
# 14      shuffle       5000  0.193314
# 15      default       5000  0.160564
# 16       static      10000  0.155333
# 17      shuffle      10000  0.294064
# 18       static      10000  0.359791
# 19       static      10000  0.161246
# 20      shuffle      10000  0.155788
# 21      default      10000  0.147601
# 22      shuffle      10000  0.294746
# 23      shuffle      10000  0.163293
# 24      default      10000  0.335229
# 25      default      10000  0.355470
# 26      shuffle      10000  0.302934
# 27      default      10000  0.355242
# 28      shuffle      10000  0.150557
# 29      default      10000  0.164885
# 30       static      10000  0.164658
# 31      default      15000  0.398226
# 32      default      15000  0.176711
# 33      shuffle      15000  0.149193
# 34      default      15000  0.153059
# 35      shuffle      15000  0.167159
# 36      shuffle      15000  0.158745
# 37      shuffle      15000  0.368433
# 38      shuffle      15000  0.384353
# 39       static      15000  0.245622
# 40       static      15000  0.388902
# 41       static      15000  0.253355
# 42      default      15000  0.384126
# 43       static      15000  0.262452
# 44      shuffle      15000  0.369570
# 45      default      15000  0.413464
# 0   longshuffle       5000  0.163066
# 1   longshuffle       5000  0.160791
# 2   longshuffle       5000  0.164203
# 3   longshuffle      10000  0.220832
# 4   longshuffle      10000  0.238117
# 5   longshuffle      10000  0.229929
# 6   longshuffle      15000  0.261315
# 7   longshuffle      15000  0.268820
# 8   longshuffle      15000  0.250398

# %%
hue_order = ['g0g1g2',
            'g2g1g0']
style_order=['static','default','shuffle', 'longshuffle']

# %%
cdata=deepcopy(df_slowness_ucf)

fig,ax = plt.subplots(1,1, figsize=(8,6))
# sns.lineplot(data=df_all, x='Iteration', y='Accuracy', hue='Curriculum', ax=ax, linewidth=0.5,
#             hue_order=hue_order)
sns.scatterplot(data=cdata, x='Iteration', y='Accuracy', hue='Curriculum', style='Condition', ax=ax, 
                legend=True, s=50,
            hue_order=hue_order, style_order=style_order)#, palette=custom_palette)
ax.axhline(y=0.14, color='gray', linestyle='solid')


ax.axvline(x=5000, color='gray', linestyle=':')
ax.axvline(x=10000, color='gray', linestyle=':')
ax.axvline(x=15000, color='gray', linestyle=':')

ax.set_xlim([1000.,16000])
ax.set_ylim([0.01,0.5])
# Add annotations to the vertical lines
# ax.set_xlim([-500,15000])
# ax.annotate('Stage 1', xy=(1000, 1), xytext=(1500, 1),
#             arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 1', xy=(5000, 0.45), xytext=(5500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 2', xy=(10000, 0.45), xytext=(10500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('End of Stage 3', xy=(15000, 0.45), xytext=(15500, 0.45),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.annotate('Untrained Network', xy=(1500, 0.2), xytext=(1500, 0.215),
#             arrowprops=dict(facecolor='black', shrink=0.05))

# for i in range(df_all.shape[0]):
#     plt.text(data['x'][i] + 0.1, data['y'][i] + 0.1, data['label'][i])


# plt.savefig('fig_ucf.pdf', dpi=300)
# Out:
# Text(15500, 0.45, 'End of Stage 3')

# %% [markdown]
# ## Mask Sampler

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/ablations/masksampler/'

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_ms = pd.DataFrame.from_records(record_list)
df_ms
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.29s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.69s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.16s/it]
#                                     fname Curriculum Condition  Iteration  \
# 0           embeddings_g0_seed_581_random     g0g1g2    random       5000
# 1    embeddings_g1_seed_581_random_pre.g0     g0g1g2    random      10000
# 2  embeddings_g2_seed_581_random_pre.g0g1     g0g1g2    random      15000
#
#    Accuracy
# 0  0.359353
# 1  0.362166
# 2  0.409986

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
        if ('gr' in tag) |\
        ('g3' in tag) |\
        ('g0g0' in tag) |\
        ('g2g2' in tag):
                continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df_mssp = pd.DataFrame.from_records(record_list)
df_mssp
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.60s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.88s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.68s/it]
#                                     fname Curriculum Condition  Iteration  \
# 0           embeddings_g0_seed_581_random     g0g1g2    random       5000
# 1    embeddings_g1_seed_581_random_pre.g0     g0g1g2    random      10000
# 2  embeddings_g2_seed_581_random_pre.g0g1     g0g1g2    random      15000
#
#    Accuracy
# 0  0.522504
# 1  0.618143
# 2  0.635724

# %% [markdown]
# ### Temp: Jun8

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/jun8/'

# %%
tagname_dict = {
    'g0':'any', 
    'g0g1': 'g0g1g2', 
    'g0g1g2': 'g0g1g2',
    'g2':'any', 
    'g2g1': 'g2g1g0', 
    'g2g1g0': 'g2g1g0',
    'g2g2': 'g2g2g2',
    'g2g2g2':'g2g2g2',
    'g0g0': 'g0g0g0', 
    'g0g0g0':'g0g0g0'}

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:02<00:00,  1.42s/it]
# 100%|█████████████████████████████████████████████| 3/3 [00:05<00:00,  1.77s/it]
# 100%|█████████████████████████████████████████████| 3/3 [00:04<00:00,  1.42s/it]
#                                  fname Curriculum Condition  Iteration  \
# 0           embeddings_g2_seed_821_sgd        any       sgd       5000
# 1           embeddings_g0_seed_821_sgd        any       sgd       5000
# 2    embeddings_g0_seed_821_sgd_pre.g0     g0g0g0       sgd      10000
# 3    embeddings_g1_seed_821_sgd_pre.g0     g0g1g2       sgd      10000
# 4    embeddings_g2_seed_821_sgd_pre.g2     g2g2g2       sgd      10000
# 5  embeddings_g2_seed_821_sgd_pre.g0g1     g0g1g2       sgd      15000
# 6  embeddings_g2_seed_821_sgd_pre.g2g2     g2g2g2       sgd      15000
# 7  embeddings_g0_seed_821_sgd_pre.g0g0     g0g0g0       sgd      15000
#
#    Accuracy
# 0  0.379044
# 1  0.225738
# 2  0.341772
# 3  0.363572
# 4  0.428973
# 5  0.407876
# 6  0.438819
# 7  0.446554

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:02<00:00,  1.21s/it]
# 100%|█████████████████████████████████████████████| 3/3 [00:04<00:00,  1.61s/it]
# 100%|█████████████████████████████████████████████| 3/3 [00:07<00:00,  2.37s/it]
#                                  fname Curriculum Condition  Iteration  \
# 0           embeddings_g2_seed_821_sgd        any       sgd       5000
# 1           embeddings_g0_seed_821_sgd        any       sgd       5000
# 2    embeddings_g0_seed_821_sgd_pre.g0     g0g0g0       sgd      10000
# 3    embeddings_g1_seed_821_sgd_pre.g0     g0g1g2       sgd      10000
# 4    embeddings_g2_seed_821_sgd_pre.g2     g2g2g2       sgd      10000
# 5  embeddings_g2_seed_821_sgd_pre.g0g1     g0g1g2       sgd      15000
# 6  embeddings_g2_seed_821_sgd_pre.g2g2     g2g2g2       sgd      15000
# 7  embeddings_g0_seed_821_sgd_pre.g0g0     g0g0g0       sgd      15000
#
#    Accuracy
# 0  0.490858
# 1  0.431083
# 2  0.437412
# 3  0.511955
# 4  0.623066
# 5  0.627286
# 6  0.665260
# 7  0.592124

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/ucf101/jun8/'

# %%
def proc_fp(fp):
    df = pd.read_csv(fp)
    
    method='sgd'
    train_score, test_score = get_separability_score(df, 'labels', method=method, ret_preds=False)
    return test_score

# %%
record_list = []
iter_per_stage = 5000
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
        if Path(fp).stem.split('_')[1]=='na':
            continue
        tag = get_tag(fp)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
        
#         if (curr=='Youngest Only') | (curr=='Oldest Only'):
#             continue
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp)
        record = {'fname': Path(fp).stem,
                  'tag': tag,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
# Out:
#   0%|                                                     | 0/2 [00:00<?, ?it/s]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  50%|██████████████████████                      | 1/2 [01:59<01:59, 119.12s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 2/2 [03:03<00:00, 91.70s/it]
#   0%|                                                     | 0/3 [00:00<?, ?it/s]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  33%|███████████████                              | 1/3 [01:00<02:01, 60.80s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  67%|██████████████████████████████               | 2/3 [01:36<00:46, 46.13s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 3/3 [02:53<00:00, 57.87s/it]
#   0%|                                                     | 0/3 [00:00<?, ?it/s]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  33%|███████████████                              | 1/3 [00:38<01:16, 38.25s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  67%|██████████████████████████████               | 2/3 [01:13<00:36, 36.30s/it]/N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 3/3 [01:48<00:00, 36.13s/it]

# %%
df_ucf = pd.DataFrame.from_records(record_list)

# %%
df_ucf
# Out:
#                                                fname     tag Curriculum  \
# 0         embeddings_model_g0_seed_821_other_821_sgd      g0        any
# 1         embeddings_model_g2_seed_821_other_821_sgd      g2        any
# 2  embeddings_model_g1_seed_821_other_821_sgd_pre.g0    g0g1     g0g1g2
# 3  embeddings_model_g2_seed_821_other_821_sgd_pre.g2    g2g2     g2g2g2
# 4  embeddings_model_g0_seed_821_other_821_sgd_pre.g0    g0g0     g0g0g0
# 5  embeddings_model_g2_seed_821_other_821_sgd_pre...  g0g1g2     g0g1g2
# 6  embeddings_model_g2_seed_821_other_821_sgd_pre...  g2g2g2     g2g2g2
# 7  embeddings_model_g0_seed_821_other_821_sgd_pre...  g0g0g0     g0g0g0
#
#    Iteration  Accuracy
# 0       5000  0.139413
# 1       5000  0.274733
# 2      10000  0.293837
# 3      10000  0.392995
# 4      10000  0.206732
# 5      15000  0.418012
# 6      15000  0.469184
# 7      15000  0.448942

# %% [markdown]
# ## Temp: Jun9

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/jun9/'

# %%
def get_seed(fp):
    stem = Path(fp).stem
    parts = stem.split('_')
    return parts[3]

def get_tag(fp):
    # g0g1g2, g2g1g0, g3g1g2, grgrgr, g2g2g2
    # g0, g2, g3, gr
    # g0g1, g2g1, g2g2, grgr, g3g1
    stem = Path(fp).stem
    parts = stem.split('_')
    glast = parts[1]
    
    if 'pre' in stem:
        gpre = parts[-1]
        gpre = gpre.replace('pre.', '')
        
        full_tag = gpre+glast
    else:
        full_tag = glast
        
    return full_tag

tagname_dict = {
    'g0':'g0 any', 
    'g0g1': 'g0g1g2', 
    'g0g1g2': 'g0g1g2',
    'g2':'g2 any', 
    'g2g1': 'g2g1g0', 
    'g2g1g0': 'g2g1g0',
    'g2g2': 'g2g2g2',
    'g2g2g2':'g2g2g2',
    'g0g0': 'g0g0g0', 
    'g0g0g0':'g0g0g0'}

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
#   0%|                                                    | 0/13 [00:00<?, ?it/s]
# embeddings_g2_seed_921_antidev
#   8%|███▍                                        | 1/13 [00:01<00:19,  1.65s/it]
# embeddings_g2_seed_922_antidev
#  15%|██████▊                                     | 2/13 [00:03<00:18,  1.69s/it]
# embeddings_g0_seed_921_yo
#  23%|██████████▏                                 | 3/13 [00:04<00:16,  1.63s/it]
# embeddings_g0_seed_926_dev
#  31%|█████████████▌                              | 4/13 [00:06<00:14,  1.62s/it]
# embeddings_g0_seed_923_dev
#  38%|████████████████▉                           | 5/13 [00:08<00:12,  1.60s/it]
# embeddings_g2_seed_921_oo
#  46%|████████████████████▎                       | 6/13 [00:09<00:11,  1.64s/it]
# embeddings_g2_seed_922_oo
#  54%|███████████████████████▋                    | 7/13 [00:11<00:10,  1.69s/it]
# embeddings_g0_seed_923_yo
#  62%|███████████████████████████                 | 8/13 [00:13<00:08,  1.73s/it]
# embeddings_g2_seed_923_oo
#  69%|██████████████████████████████▍             | 9/13 [00:14<00:06,  1.62s/it]
# embeddings_g0_seed_922_dev
#  77%|█████████████████████████████████          | 10/13 [00:16<00:04,  1.66s/it]
# embeddings_g0_seed_921_dev
#  85%|████████████████████████████████████▍      | 11/13 [00:18<00:03,  1.60s/it]
# embeddings_g0_seed_926_yo
#  92%|███████████████████████████████████████▋   | 12/13 [00:19<00:01,  1.55s/it]
# embeddings_g0_seed_922_yo
# 100%|███████████████████████████████████████████| 13/13 [00:21<00:00,  1.66s/it]
#   0%|                                                    | 0/13 [00:00<?, ?it/s]
# embeddings_g1_seed_922_dev_pre.g0
#   8%|███▍                                        | 1/13 [00:01<00:20,  1.68s/it]
# embeddings_g0_seed_921_yo_pre.g0
#  15%|██████▊                                     | 2/13 [00:03<00:17,  1.63s/it]
# embeddings_g0_seed_922_yo_pre.g0
#  23%|██████████▏                                 | 3/13 [00:05<00:16,  1.67s/it]
# embeddings_g2_seed_923_oo_pre.g2
#  31%|█████████████▌                              | 4/13 [00:06<00:15,  1.73s/it]
# embeddings_g1_seed_923_dev_pre.g0
#  38%|████████████████▉                           | 5/13 [00:08<00:13,  1.69s/it]
# embeddings_g2_seed_921_oo_pre.g2
#  46%|████████████████████▎                       | 6/13 [00:10<00:11,  1.66s/it]
# embeddings_g1_seed_926_dev_pre.g0
#  54%|███████████████████████▋                    | 7/13 [00:11<00:09,  1.64s/it]
# embeddings_g2_seed_922_oo_pre.g2
#  62%|███████████████████████████                 | 8/13 [00:13<00:08,  1.74s/it]
# embeddings_g0_seed_923_yo_pre.g0
#  69%|██████████████████████████████▍             | 9/13 [00:15<00:07,  1.79s/it]
# embeddings_g0_seed_926_yo_pre.g0
#  77%|█████████████████████████████████          | 10/13 [00:16<00:05,  1.70s/it]
# embeddings_g1_seed_921_dev_pre.g0
#  85%|████████████████████████████████████▍      | 11/13 [00:19<00:03,  1.95s/it]
# embeddings_g1_seed_922_antidev_pre.g2
#  92%|███████████████████████████████████████▋   | 12/13 [00:21<00:01,  1.85s/it]
# embeddings_g1_seed_921_antidev_pre.g2
# 100%|███████████████████████████████████████████| 13/13 [00:22<00:00,  1.77s/it]
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# embeddings_g0_seed_922_yo_pre.g0g0
#   8%|███▋                                        | 1/12 [00:01<00:19,  1.73s/it]
# embeddings_g2_seed_923_dev_pre.g0g1
#  17%|███████▎                                    | 2/12 [00:03<00:17,  1.78s/it]
# embeddings_g2_seed_921_dev_pre.g0g1
#  25%|███████████                                 | 3/12 [00:05<00:15,  1.68s/it]
# embeddings_g2_seed_922_dev_pre.g0g1
#  33%|██████████████▋                             | 4/12 [00:07<00:14,  1.81s/it]
# embeddings_g2_seed_921_oo_pre.g2g2
#  42%|██████████████████▎                         | 5/12 [00:08<00:11,  1.66s/it]
# embeddings_g2_seed_923_oo_pre.g2g2
#  50%|██████████████████████                      | 6/12 [00:10<00:10,  1.68s/it]
# embeddings_g2_seed_922_oo_pre.g2g2
#  58%|█████████████████████████▋                  | 7/12 [00:11<00:08,  1.62s/it]
# embeddings_g2_seed_926_dev_pre.g0g1
#  67%|█████████████████████████████▎              | 8/12 [00:13<00:06,  1.61s/it]
# embeddings_g0_seed_922_antidev_pre.g2g1
#  75%|█████████████████████████████████           | 9/12 [00:15<00:05,  1.67s/it]
# embeddings_g0_seed_921_antidev_pre.g2g1
#  83%|███████████████████████████████████▊       | 10/12 [00:16<00:03,  1.71s/it]
# embeddings_g0_seed_921_yo_pre.g0g0
#  92%|███████████████████████████████████████▍   | 11/12 [00:18<00:01,  1.69s/it]
# embeddings_g0_seed_926_yo_pre.g0g0
# 100%|███████████████████████████████████████████| 12/12 [00:20<00:00,  1.68s/it]
#                                       fname Curriculum Condition  Iteration  \
# 0            embeddings_g2_seed_921_antidev     g2 any   antidev       5000
# 1            embeddings_g2_seed_922_antidev     g2 any   antidev       5000
# 2                 embeddings_g0_seed_921_yo     g0 any        yo       5000
# 3                embeddings_g0_seed_926_dev     g0 any       dev       5000
# 4                embeddings_g0_seed_923_dev     g0 any       dev       5000
# 5                 embeddings_g2_seed_921_oo     g2 any        oo       5000
# 6                 embeddings_g2_seed_922_oo     g2 any        oo       5000
# 7                 embeddings_g0_seed_923_yo     g0 any        yo       5000
# 8                 embeddings_g2_seed_923_oo     g2 any        oo       5000
# 9                embeddings_g0_seed_922_dev     g0 any       dev       5000
# 10               embeddings_g0_seed_921_dev     g0 any       dev       5000
# 11                embeddings_g0_seed_926_yo     g0 any        yo       5000
# 12                embeddings_g0_seed_922_yo     g0 any        yo       5000
# 13        embeddings_g1_seed_922_dev_pre.g0     g0g1g2       dev      10000
# 14         embeddings_g0_seed_921_yo_pre.g0     g0g0g0        yo      10000
# 15         embeddings_g0_seed_922_yo_pre.g0     g0g0g0        yo      10000
# 16         embeddings_g2_seed_923_oo_pre.g2     g2g2g2        oo      10000
# 17        embeddings_g1_seed_923_dev_pre.g0     g0g1g2       dev      10000
# 18         embeddings_g2_seed_921_oo_pre.g2     g2g2g2        oo      10000
# 19        embeddings_g1_seed_926_dev_pre.g0     g0g1g2       dev      10000
# 20         embeddings_g2_seed_922_oo_pre.g2     g2g2g2        oo      10000
# 21         embeddings_g0_seed_923_yo_pre.g0     g0g0g0        yo      10000
# 22         embeddings_g0_seed_926_yo_pre.g0     g0g0g0        yo      10000
# 23        embeddings_g1_seed_921_dev_pre.g0     g0g1g2       dev      10000
# 24    embeddings_g1_seed_922_antidev_pre.g2     g2g1g0   antidev      10000
# 25    embeddings_g1_seed_921_antidev_pre.g2     g2g1g0   antidev      10000
# 26       embeddings_g0_seed_922_yo_pre.g0g0     g0g0g0        yo      15000
# 27      embeddings_g2_seed_923_dev_pre.g0g1     g0g1g2       dev      15000
# 28      embeddings_g2_seed_921_dev_pre.g0g1     g0g1g2       dev      15000
# 29      embeddings_g2_seed_922_dev_pre.g0g1     g0g1g2       dev      15000
# 30       embeddings_g2_seed_921_oo_pre.g2g2     g2g2g2        oo      15000
# 31       embeddings_g2_seed_923_oo_pre.g2g2     g2g2g2        oo      15000
# 32       embeddings_g2_seed_922_oo_pre.g2g2     g2g2g2        oo      15000
# 33      embeddings_g2_seed_926_dev_pre.g0g1     g0g1g2       dev      15000
# 34  embeddings_g0_seed_922_antidev_pre.g2g1     g2g1g0   antidev      15000
# 35  embeddings_g0_seed_921_antidev_pre.g2g1     g2g1g0   antidev      15000
# 36       embeddings_g0_seed_921_yo_pre.g0g0     g0g0g0        yo      15000
# 37       embeddings_g0_seed_926_yo_pre.g0g0     g0g0g0        yo      15000
#
#     Accuracy
# 0   0.254571
# 1   0.277075
# 2   0.395921
# 3   0.422644
# 4   0.398031
# 5   0.264416
# 6   0.244023
# 7   0.430380
# 8   0.255977
# 9   0.408579
# 10  0.416315
# 11  0.414909
# 12  0.402250
# 13  0.442335
# 14  0.477496
# 15  0.444444
# 16  0.274262
# 17  0.414909
# 18  0.267229
# 19  0.456399
# 20  0.237693
# 21  0.431786
# 22  0.463432
# 23  0.452883
# 24  0.251758
# 25  0.341069
# 26  0.484529
# 27  0.416315
# 28  0.454290
# 29  0.486639
# 30  0.237693
# 31  0.271449
# 32  0.241210
# 33  0.454993
# 34  0.413502
# 35  0.432489
# 36  0.474684
# 37  0.472574

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
# 100%|███████████████████████████████████████████| 13/13 [00:24<00:00,  1.86s/it]
# 100%|███████████████████████████████████████████| 13/13 [00:24<00:00,  1.87s/it]
# 100%|███████████████████████████████████████████| 12/12 [00:21<00:00,  1.81s/it]
#                                       fname Curriculum Condition  Iteration  \
# 0            embeddings_g2_seed_921_antidev     g2 any   antidev       5000
# 1            embeddings_g2_seed_922_antidev     g2 any   antidev       5000
# 2                 embeddings_g0_seed_921_yo     g0 any        yo       5000
# 3                embeddings_g0_seed_926_dev     g0 any       dev       5000
# 4                embeddings_g0_seed_923_dev     g0 any       dev       5000
# 5                 embeddings_g2_seed_921_oo     g2 any        oo       5000
# 6                 embeddings_g2_seed_922_oo     g2 any        oo       5000
# 7                 embeddings_g0_seed_923_yo     g0 any        yo       5000
# 8                 embeddings_g2_seed_923_oo     g2 any        oo       5000
# 9                embeddings_g0_seed_922_dev     g0 any       dev       5000
# 10               embeddings_g0_seed_921_dev     g0 any       dev       5000
# 11                embeddings_g0_seed_926_yo     g0 any        yo       5000
# 12                embeddings_g0_seed_922_yo     g0 any        yo       5000
# 13        embeddings_g1_seed_922_dev_pre.g0     g0g1g2       dev      10000
# 14         embeddings_g0_seed_921_yo_pre.g0     g0g0g0        yo      10000
# 15         embeddings_g0_seed_922_yo_pre.g0     g0g0g0        yo      10000
# 16         embeddings_g2_seed_923_oo_pre.g2     g2g2g2        oo      10000
# 17        embeddings_g1_seed_923_dev_pre.g0     g0g1g2       dev      10000
# 18         embeddings_g2_seed_921_oo_pre.g2     g2g2g2        oo      10000
# 19        embeddings_g1_seed_926_dev_pre.g0     g0g1g2       dev      10000
# 20         embeddings_g2_seed_922_oo_pre.g2     g2g2g2        oo      10000
# 21         embeddings_g0_seed_923_yo_pre.g0     g0g0g0        yo      10000
# 22         embeddings_g0_seed_926_yo_pre.g0     g0g0g0        yo      10000
# 23        embeddings_g1_seed_921_dev_pre.g0     g0g1g2       dev      10000
# 24    embeddings_g1_seed_922_antidev_pre.g2     g2g1g0   antidev      10000
# 25    embeddings_g1_seed_921_antidev_pre.g2     g2g1g0   antidev      10000
# 26       embeddings_g0_seed_922_yo_pre.g0g0     g0g0g0        yo      15000
# 27      embeddings_g2_seed_923_dev_pre.g0g1     g0g1g2       dev      15000
# 28      embeddings_g2_seed_921_dev_pre.g0g1     g0g1g2       dev      15000
# 29      embeddings_g2_seed_922_dev_pre.g0g1     g0g1g2       dev      15000
# 30       embeddings_g2_seed_921_oo_pre.g2g2     g2g2g2        oo      15000
# 31       embeddings_g2_seed_923_oo_pre.g2g2     g2g2g2        oo      15000
# 32       embeddings_g2_seed_922_oo_pre.g2g2     g2g2g2        oo      15000
# 33      embeddings_g2_seed_926_dev_pre.g0g1     g0g1g2       dev      15000
# 34  embeddings_g0_seed_922_antidev_pre.g2g1     g2g1g0   antidev      15000
# 35  embeddings_g0_seed_921_antidev_pre.g2g1     g2g1g0   antidev      15000
# 36       embeddings_g0_seed_921_yo_pre.g0g0     g0g0g0        yo      15000
# 37       embeddings_g0_seed_926_yo_pre.g0g0     g0g0g0        yo      15000
#
#     Accuracy
# 0   0.424051
# 1   0.414909
# 2   0.577356
# 3   0.575949
# 4   0.616737
# 5   0.456399
# 6   0.447961
# 7   0.565401
# 8   0.407173
# 9   0.580872
# 10  0.561181
# 11  0.567511
# 12  0.576653
# 13  0.616034
# 14  0.597750
# 15  0.601969
# 16  0.417722
# 17  0.641350
# 18  0.432489
# 19  0.613221
# 20  0.436006
# 21  0.627286
# 22  0.613221
# 23  0.613924
# 24  0.459212
# 25  0.484529
# 26  0.623769
# 27  0.654712
# 28  0.636428
# 29  0.627286
# 30  0.451477
# 31  0.426864
# 32  0.416315
# 33  0.641350
# 34  0.563994
# 35  0.592124
# 36  0.613221
# 37  0.599156

# %% [markdown]
# ## Temp: Jun10

# %%
tagname_dict = {
    'g0':'g0 any', 
    'g0g1': 'g0g1g2', 
    'g0g1g2': 'g0g1g2',
    'g2':'g2 any', 
    'g2g1': 'g2g1g0', 
    'g2g1g0': 'g2g1g0',
    'g2g2': 'g2g2g2',
    'g2g2g2':'g2g2g2',
    'g0g0': 'g0g0g0', 
    'g0g0g0':'g0g0g0'}

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/jun10/'

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [00:06<00:00,  1.54s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:06<00:00,  1.69s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.80s/it]
#                                   fname Curriculum Condition  Iteration  \
# 0            embeddings_g0_seed_927_dev     g0 any       dev       5000
# 1             embeddings_g0_seed_927_yo     g0 any        yo       5000
# 2             embeddings_g0_seed_923_yo     g0 any        yo       5000
# 3             embeddings_g2_seed_927_oo     g2 any        oo       5000
# 4      embeddings_g0_seed_923_yo_pre.g0     g0g0g0        yo      10000
# 5      embeddings_g2_seed_927_oo_pre.g2     g2g2g2        oo      10000
# 6     embeddings_g1_seed_927_dev_pre.g0     g0g1g2       dev      10000
# 7      embeddings_g0_seed_927_yo_pre.g0     g0g0g0        yo      10000
# 8    embeddings_g0_seed_923_yo_pre.g0g0     g0g0g0        yo      15000
# 9   embeddings_g2_seed_927_dev_pre.g0g1     g0g1g2       dev      15000
# 10   embeddings_g2_seed_927_oo_pre.g2g2     g2g2g2        oo      15000
# 11   embeddings_g0_seed_927_yo_pre.g0g0     g0g0g0        yo      15000
#
#     Accuracy
# 0   0.402250
# 1   0.406470
# 2   0.409283
# 3   0.263010
# 4   0.426160
# 5   0.247539
# 6   0.407876
# 7   0.428270
# 8   0.442335
# 9   0.444444
# 10  0.269339
# 11  0.438819

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [00:06<00:00,  1.73s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:05<00:00,  1.50s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:05<00:00,  1.43s/it]
#                                   fname Curriculum Condition  Iteration  \
# 0            embeddings_g0_seed_927_dev     g0 any       dev       5000
# 1             embeddings_g0_seed_927_yo     g0 any        yo       5000
# 2             embeddings_g0_seed_923_yo     g0 any        yo       5000
# 3             embeddings_g2_seed_927_oo     g2 any        oo       5000
# 4      embeddings_g0_seed_923_yo_pre.g0     g0g0g0        yo      10000
# 5      embeddings_g2_seed_927_oo_pre.g2     g2g2g2        oo      10000
# 6     embeddings_g1_seed_927_dev_pre.g0     g0g1g2       dev      10000
# 7      embeddings_g0_seed_927_yo_pre.g0     g0g0g0        yo      10000
# 8    embeddings_g0_seed_923_yo_pre.g0g0     g0g0g0        yo      15000
# 9   embeddings_g2_seed_927_dev_pre.g0g1     g0g1g2       dev      15000
# 10   embeddings_g2_seed_927_oo_pre.g2g2     g2g2g2        oo      15000
# 11   embeddings_g0_seed_927_yo_pre.g0g0     g0g0g0        yo      15000
#
#     Accuracy
# 0   0.613924
# 1   0.601969
# 2   0.620253
# 3   0.450774
# 4   0.635724
# 5   0.433896
# 6   0.650492
# 7   0.654008
# 8   0.668073
# 9   0.692686
# 10  0.413502
# 11  0.673699

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/ucf101/jun10/'

# %%
def get_tag(fp):
    # g0g1g2, g2g1g0, g3g1g2, grgrgr, g2g2g2
    # g0, g2, g3, gr
    # g0g1, g2g1, g2g2, grgr, g3g1
    stem = Path(fp).stem
    parts = stem.split('_')
    glast = parts[2]
    
    if 'pre' in stem:
        gpre = parts[-1]
        gpre = gpre.replace('pre.', '')
        
        full_tag = gpre+glast
    else:
        full_tag = glast
    return full_tag

def get_ablation_cond(fp):
    stem = Path(fp).stem
    parts = stem.split('_')
#     other_id = parts[5]
    cond = parts[7]
    return cond

def proc_fp(fp):
    df = pd.read_csv(fp)
    
    method='sgd'
    train_score, test_score = get_separability_score(df, 'labels', method=method, ret_preds=False)
    return test_score

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(3,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
        print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
        print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp)
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
# embeddings_model_g2_seed_927_other_927_dev_pre.g0g1
# dev
#  25%|███████████▎                                 | 1/4 [00:28<01:25, 28.63s/it]
# embeddings_model_g0_seed_923_other_923_yo_pre.g0g0
# yo
# /N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  50%|██████████████████████▌                      | 2/4 [01:04<01:05, 32.81s/it]
# embeddings_model_g0_seed_927_other_927_yo_pre.g0g0
# yo
# /N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
#  75%|█████████████████████████████████▊           | 3/4 [01:36<00:32, 32.57s/it]
# embeddings_model_g2_seed_927_other_927_oo_pre.g2g2
# oo
# /N/soft/sles15/deeplearning/Python-3.10.5/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 4/4 [03:09<00:00, 47.38s/it]
#                                                fname Curriculum Condition  \
# 0  embeddings_model_g2_seed_927_other_927_dev_pre...     g0g1g2       dev
# 1  embeddings_model_g0_seed_923_other_923_yo_pre....     g0g0g0        yo
# 2  embeddings_model_g0_seed_927_other_927_yo_pre....     g0g0g0        yo
# 3  embeddings_model_g2_seed_927_other_927_oo_pre....     g2g2g2        oo
#
#    Iteration  Accuracy
# 0      15000  0.443029
# 1      15000  0.459859
# 2      15000  0.478053
# 3      15000  0.136002

# %% [markdown]
# ## June 11
# Long training. only compare 012, 000. 2 seeds

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/jun11/'

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [00:06<00:00,  1.74s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.83s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.85s/it]
#                                   fname Curriculum Condition  Iteration  \
# 0             embeddings_g0_seed_142_yo     g0 any        yo       5000
# 1             embeddings_g0_seed_141_yo     g0 any        yo       5000
# 2            embeddings_g0_seed_142_dev     g0 any       dev       5000
# 3            embeddings_g0_seed_141_dev     g0 any       dev       5000
# 4      embeddings_g0_seed_142_yo_pre.g0     g0g0g0        yo      10000
# 5     embeddings_g1_seed_142_dev_pre.g0     g0g1g2       dev      10000
# 6     embeddings_g1_seed_141_dev_pre.g0     g0g1g2       dev      10000
# 7      embeddings_g0_seed_141_yo_pre.g0     g0g0g0        yo      10000
# 8    embeddings_g0_seed_142_yo_pre.g0g0     g0g0g0        yo      15000
# 9   embeddings_g2_seed_141_dev_pre.g0g1     g0g1g2       dev      15000
# 10  embeddings_g2_seed_142_dev_pre.g0g1     g0g1g2       dev      15000
# 11   embeddings_g0_seed_141_yo_pre.g0g0     g0g0g0        yo      15000
#
#     Accuracy
# 0   0.443038
# 1   0.457103
# 2   0.447961
# 3   0.443038
# 4   0.433896
# 5   0.430380
# 6   0.462025
# 7   0.469058
# 8   0.439522
# 9   0.459212
# 10  0.421238
# 11  0.476793

# %%
record_list = []
iter_per_stage = 5000 #@@
for stage in range(1,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [00:05<00:00,  1.25s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.13it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.26it/s]
#                                   fname Curriculum Condition  Iteration  \
# 0             embeddings_g0_seed_142_yo     g0 any        yo       5000
# 1             embeddings_g0_seed_141_yo     g0 any        yo       5000
# 2            embeddings_g0_seed_142_dev     g0 any       dev       5000
# 3            embeddings_g0_seed_141_dev     g0 any       dev       5000
# 4      embeddings_g0_seed_142_yo_pre.g0     g0g0g0        yo      10000
# 5     embeddings_g1_seed_142_dev_pre.g0     g0g1g2       dev      10000
# 6     embeddings_g1_seed_141_dev_pre.g0     g0g1g2       dev      10000
# 7      embeddings_g0_seed_141_yo_pre.g0     g0g0g0        yo      10000
# 8    embeddings_g0_seed_142_yo_pre.g0g0     g0g0g0        yo      15000
# 9   embeddings_g2_seed_141_dev_pre.g0g1     g0g1g2       dev      15000
# 10  embeddings_g2_seed_142_dev_pre.g0g1     g0g1g2       dev      15000
# 11   embeddings_g0_seed_141_yo_pre.g0g0     g0g0g0        yo      15000
#
#     Accuracy
# 0   0.696906
# 1   0.710267
# 2   0.689170
# 3   0.699719
# 4   0.741210
# 5   0.748242
# 6   0.767932
# 7   0.746132
# 8   0.777075
# 9   0.789733
# 10  0.763713
# 11  0.786920

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/ucf101/jun11/'

def get_tag(fp):
    # g0g1g2, g2g1g0, g3g1g2, grgrgr, g2g2g2
    # g0, g2, g3, gr
    # g0g1, g2g1, g2g2, grgr, g3g1
    stem = Path(fp).stem
    parts = stem.split('_')
    glast = parts[2]
    
    if 'pre' in stem:
        gpre = parts[-1]
        gpre = gpre.replace('pre.', '')
        
        full_tag = gpre+glast
    else:
        full_tag = glast
    return full_tag

def get_ablation_cond(fp):
    stem = Path(fp).stem
    parts = stem.split('_')
#     other_id = parts[5]
    cond = parts[7]
    return cond

def proc_fp(fp):
    df = pd.read_csv(fp)
    
    method='sgd'
    train_score, test_score = get_separability_score(df, 'labels', method=method, ret_preds=False)
    return test_score


record_list = []
iter_per_stage = 5000 #@@
for stage in range(3,4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
        print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
        print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp)
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
# embeddings_model_g0_seed_142_other_142_yo_pre.g0g0
# yo
#  25%|███████████▎                                 | 1/4 [00:26<01:19, 26.64s/it]
# embeddings_model_g2_seed_141_other_141_dev_pre.g0g1
# dev
#  50%|██████████████████████▌                      | 2/4 [00:46<00:45, 22.91s/it]
# embeddings_model_g2_seed_142_other_142_dev_pre.g0g1
# dev
#  75%|█████████████████████████████████▊           | 3/4 [01:16<00:25, 25.76s/it]
# embeddings_model_g0_seed_141_other_141_yo_pre.g0g0
# yo
# 100%|█████████████████████████████████████████████| 4/4 [01:39<00:00, 24.78s/it]
#                                                fname Curriculum Condition  \
# 0  embeddings_model_g0_seed_142_other_142_yo_pre....     g0g0g0        yo
# 1  embeddings_model_g2_seed_141_other_141_dev_pre...     g0g1g2       dev
# 2  embeddings_model_g2_seed_142_other_142_dev_pre...     g0g1g2       dev
# 3  embeddings_model_g0_seed_141_other_141_yo_pre....     g0g0g0        yo
#
#    Iteration  Accuracy
# 0      15000  0.511940
# 1      15000  0.539459
# 2      15000  0.479645
# 3      15000  0.569024

# %% [markdown]
# ### June 12

# %%
emb_root = '/N/project/baby_vision_curriculum/trained_models/generative/v2/benchmarks/toybox/jun12/'

# %%
record_list = []
iter_per_stage = 10000 #@@
for stage in range(1,2):#4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'category')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.66s/it]
#                        fname Curriculum Condition  Iteration  Accuracy
# 0  embeddings_g2_seed_143_oo     g2g1g0        oo      10000  0.379747
# 1  embeddings_g0_seed_141_yo     g0g1g2        yo      10000  0.273558

# %%
record_list = []
iter_per_stage = 10000 #@@
for stage in range(1,2):#4):
    emb_dir = emb_root+'s'+str(stage)+'/'
    fpathlist = [emb_dir+fname
                for fname in os.listdir(emb_dir)
                if Path(emb_dir+fname).suffix=='.csv']
    for i, fp in enumerate(tqdm(fpathlist)):
#         print(Path(fp).stem)
        tag = get_tag(fp)
#         if ('gr' in tag) |\
#         ('g3' in tag) |\
#         ('g0g0' in tag) |\
#         ('g2g2' in tag):
#                 continue # skip other curricula
#         print(tag)
        curr = tagname_dict[tag]
        cond = get_ablation_cond(fp)
#         print(cond)
#         tag = tag.replace('g3','ga')
        score = proc_fp(fp, 'transformation')
        record = {'fname': Path(fp).stem,
                  'Curriculum': curr,
                  'Condition': cond,
                 'Iteration': iter_per_stage*stage,
                  'Accuracy': score}
        record_list.append(deepcopy(record))
df = pd.DataFrame.from_records(record_list)
df
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:02<00:00,  1.45s/it]
#                        fname Curriculum Condition  Iteration  Accuracy
# 0  embeddings_g2_seed_143_oo     g2g1g0        oo      10000  0.650492
# 1  embeddings_g0_seed_141_yo     g0g1g2        yo      10000  0.449367
